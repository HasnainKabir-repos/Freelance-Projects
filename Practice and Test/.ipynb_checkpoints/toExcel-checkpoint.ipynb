# %%
import pandas as pd
import numpy as np
data = pd.read_table('text.txt', sep = '\t')
data.set_index('Serial No.')
data
# Out:
#     Serial No.                                              Topic
# 0          1.0       Best hospital uniforms exporter company 1000
# 1          2.0                 Best dress manufacturer in BD 1000
# 2          3.0        Best skirt manufacturing company in BD 1000
# 3          4.0                       BD garments association 2000
# 4          5.0                  Posh garments: best clothing 1500
# 5          6.0          Posh garments: Lingerie manufacturer 1500
# 6          7.0  Top shipping agent in BD 1000 (this one was wr...
# 7          8.0                   Best crewing company in CTG 1000
# 8          9.0                     Top crewing agency in CTG 1000
# 9         10.0       ABM water company: best water treatment 1000
# 10        11.0              ABM water company: surface water 1000
# 11        12.0                 How long do RO membranes last 1000
# 12        13.0        Importance of effluent treatment plant 1000
# ...

# %%
# Out:
#      Serial No.                                              Topic
# NaN         1.0       Best hospital uniforms exporter company 1000
# NaN         2.0                 Best dress manufacturer in BD 1000
# NaN         3.0        Best skirt manufacturing company in BD 1000
# NaN         4.0                       BD garments association 2000
# NaN         5.0                  Posh garments: best clothing 1500
# NaN         6.0          Posh garments: Lingerie manufacturer 1500
# NaN         7.0  Top shipping agent in BD 1000 (this one was wr...
# NaN         8.0                   Best crewing company in CTG 1000
# NaN         9.0                     Top crewing agency in CTG 1000
# NaN        10.0       ABM water company: best water treatment 1000
# NaN        11.0              ABM water company: surface water 1000
# NaN        12.0                 How long do RO membranes last 1000
# NaN        13.0        Importance of effluent treatment plant 1000
# ...
