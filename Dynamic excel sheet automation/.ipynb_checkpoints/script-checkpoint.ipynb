# %%
import openpyxl
import sys
import re

# %%
shipping_data = []

row_index = 1

try:
    
    print("Processing Please wait...")
    
    book = openpyxl.load_workbook('ClientIndexFGT.xlsx')
    sheet = book['Sheet1']
    
    while row_index <= sheet.max_row:

        row = sheet[row_index]
        B = row[1].value   

        if row_index >= 2299:
            break

        if len(str(B)) > 2 and row[0] != 'P':

            names = []
            locations = []
            FTS = ""

            names.append(B)

            if row[4].value == "FTS-1":
                FTS = "FTS-1"
            elif row[4].value == "FTS-2":
                FTS = "FTS-2"

            new_row_index = row_index + 1

            while new_row_index <= sheet.max_row:

                inner_row = sheet[new_row_index]
                new_B = inner_row[1].value

                if len(str(new_B)) > 2 and inner_row[0].value != 'P':

                    names.append(new_B)

                    if inner_row[4].value == "FTS-1":
                        FTS = "FTS-1"
                    elif inner_row[4].value == "FTS-2":
                        FTS = "FTS-2"
                else:
                    break

                new_row_index += 1

            while new_row_index <= sheet.max_row:

                resume_row = sheet[new_row_index]

                if len(str(resume_row[1].value)) <= 2 and resume_row[0].value == 'P':
                    locations.append(resume_row[2].value)
                else:
                    break

                new_row_index += 1

            data = {"Names" : names, "Locations" : locations, "FTS" : FTS}

            shipping_data.append(data)

        row_index = new_row_index
        
    print("Data Fetched Successfully") 
    
except FileNotFoundError:
    
    print('File not found, please keep the excel file in the same folder as this script')
    sys.exit(1)
    
except openpyxl.utils.exceptions.InvalidFileException:
    
    print('Invalid Excel file format. Please check the file format.')
    sys.exit(1)
    
except Exception as e:
    
    print('An error occurred: '+ str(e))
    sys.exit(1)
# Out:
# Processing Please wait...
# Data Fetched Successfully

# %%
shipping_data
# Out:
# [{'Names': ['FLORIDA GAS TRANSMISSION COMPANY, LLC',
#    'FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'BOURBON LINE FROM MS CANYON 268',
#    'CHANDELEUR SOUND 51',
#    'COGNAC LINE (TGPL) FROM MS CANYON 1',
#    'COLUMBIA GULF-LAFAYETTE',
#    'EGAN HUB (REC)',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GSPL ST LANDRY',
#    'HPL TEXOMA (REC)',
#    'LRC WHITE CASTLE',
#    'MAGNET WITHERS-ENTERPRISE',
#    'MAIN PASS 108',
#    'MARKHAM-GULF SHORE',
#    'MATAGORDA 631/658 SS I/C',
#    'MISSISSIPPI CANYON 194',
#    'MISSISSIPPI CANYON 311',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SESH MOBILE BAY',
#    'SNG COLUMBIA-SHADYSIDE',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'SNG TENN TOCA',
#    'ST GABRIEL',
#    'STUARDS BLUFF',
#    'TEJAS SMITH PT',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'TRUNKLINE VERMILION',
#    'TX GAS EUNICE',
#    'VK989',
#    'CAPE CANAVERAL-FPL',
#    'CUTLER-FPL',
#    'E PALATKA-FPL',
#    'FT MYERS-FPL',
#    'LAUDERDALE A-FPL',
#    'LAUDERDALE B-FPL',
#    'MANATEE-FPL',
#    'MARTIN-FPL',
#    'PORT EVERGLADES ENERGY CENTER M&R-F',
#    'PORT EVERGLADES-FPL',
#    'PUTNAM-FPL',
#    'RIVIERA EAST-FPL',
#    'RIVIERA WEST-FPL',
#    'RIVIERA-FPL',
#    'SANFORD-FPL',
#    'TURKEY POINT NORTH-FPL',
#    'TURKEY PT-FPL'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CUTRALE CITRUS JUICES USA, INC.', 'BP ENERGY COMPANY'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'LITTLE LAKE',
#    'MAIN PASS 289-VK ENTERPRISE',
#    'MAIN PASS 296',
#    'MAIN PASS 68-NOBLE',
#    'MARKHAM-GULF SHORE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG TX GAS-KOSCIUSKO',
#    'ST GABRIEL',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'AUBURNDALE-CUTRALE',
#    'LEESBURG',
#    'MINUTE MAID PLYMOUTH'],
#   'FTS': 'FTS-2'},
#  {'Names': ['LAKELAND, CITY OF'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'EGP COW ISLAND PLT OUTLET',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'MAIN PASS 108',
#    'MAIN PASS 77',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'PEARL RIVER',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'SNG HIGH POINT-TOCA',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'VK989',
#    'LAKELAND GENERATING',
#    'LAKELAND MCINTOSH'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['CAPE CANAVERAL-FPL',
#    'FT MYERS-FPL',
#    'GULF POWER SMITH PLT (DEL)',
#    'LAUDERDALE A-FPL',
#    'LAUDERDALE B-FPL',
#    'MANATEE-FPL',
#    'MARTIN-FPL',
#    'PORT EVERGLADES ENERGY CENTER M&R-F',
#    'PUTNAM-FPL',
#    'RIVIERA EAST-FPL',
#    'RIVIERA WEST-FPL',
#    'SANFORD-FPL',
#    'TURKEY POINT NORTH-FPL'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL MERRILL',
#    'NGPL VERMILION',
#    'SNG COLUMBIA-SHADYSIDE',
#    'SNG- ACADIAN-IBERVILLE',
#    'TENN CARNES (REC)'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'GSPL MOBILE BAY-FGT CAPACITY',
#    'GSPL MOBILE BAY-GULF SOUTH CAPACITY',
#    'NGPL VERMILION',
#    'TRUNKLINE VERMILION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'SESH MOBILE BAY',
#    'SNG COLUMBIA-SHADYSIDE',
#    'SNG HIGH POINT-TOCA',
#    'SNG TENN TOCA',
#    'SNG- ACADIAN-IBERVILLE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'TRUNKLINE VERMILION',
#    'TX GAS EUNICE'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['GSPL MOBILE BAY-FGT CAPACITY', 'GULF POWER SMITH PLT (DEL)'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['DESTIN P/L', 'GSPL MOBILE BAY-FGT CAPACITY'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'BARTOW B-CUC',
#    'DELAND DIVISION',
#    'NEW SMYRNA-FPU',
#    'PIONEER GATE-NUI',
#    'SANFORD DIVISION',
#    'WEST PALM BEACH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['DESTIN P/L',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'BOCA RATON-FPU',
#    'BOYNTON CTG-FPU',
#    'DELAND DIVISION',
#    'DELAND SOUTH-FPU',
#    'DELAND-FPU',
#    'LAKE WORTH SOUTH-FPU',
#    'LAKE WORTH-FPU',
#    'RIVIERA BEACH NORTH-FPU',
#    'SANFORD DIVISION',
#    'SANFORD W-FPU',
#    'SANFORD-FPU',
#    'W PALM BEACH W-FPU',
#    'W PALM BEACH-FPU',
#    'WEST PALM BEACH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['FRISCO ACADIAN',
#    'BOCA RATON-FPU',
#    'NEW SMYRNA-FPU',
#    'PIONEER GATE-NUI',
#    'WEST PALM BEACH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['DESTIN P/L',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SANFORD DIVISION',
#    'SANFORD-FPU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['DESTIN P/L', 'SANFORD DIVISION', 'SANFORD-FPU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['DESTIN P/L',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'PIONEER GATE-NUI',
#    'W PALM BEACH-FPU',
#    'WEST PALM BEACH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'BARTOW B-CUC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'DESTIN P/L',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'KISSIMMEE CANE ISLAND',
#    'KISSIMMEE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA GAS UTILITY', 'LAKELAND, CITY OF', 'GAS SOUTH, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'LRC KAPLAN',
#    'LRC WHITE CASTLE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG CYPRESS',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'CLEARWATER DIVISION',
#    'K 107696 PT GROUP',
#    'K 111700 PT GROUP',
#    'KISSIMMEE CANE ISLAND',
#    'KISSIMMEE DIVISION',
#    'LEESBURG',
#    'TREASURE COAST ENERGY CENTER',
#    'W LAKE WORTH CTG-FGU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'KISSIMMEE CANE ISLAND',
#    'KISSIMMEE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['KISSIMMEE UTILITY AUTHORITY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'DESTIN P/L',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'KISSIMMEE CANE ISLAND',
#    'KISSIMMEE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CITY OF CLEARWATER', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST LANDRY',
#    'LRC WHITE CASTLE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'CLEARWATER DIVISION',
#    'CLEARWATER EAST',
#    'CLEARWATER NORTH',
#    'CLEARWATER SOUTH',
#    'CLEARWATER TRINITY'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CITY OF LEESBURG', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH', 'LEESBURG'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-2'},
#  {'Names': ['KISSIMMEE UTILITY AUTHORITY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'KISSIMMEE CANE ISLAND'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['SNG CYPRESS',
#    'K 107696 PT GROUP',
#    'OLEANDER B-PGS',
#    'OLEANDER POWER CT',
#    'STANTON-OUC',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['HPL MAGNET WITHERS',
#    'LRC KAPLAN',
#    'LRC WHITE CASTLE',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'TRANSCO ST HELENA',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY'],
#   'Locations': ['HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['DESTIN P/L',
#    'INDIAN RIVER CTG-RELIANT',
#    'K 111700 PT GROUP',
#    'RELIANT HOLOPAW'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CITY OF LAKE WORTH BEACH', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'W LAKE WORTH CTG-FGU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['REEDY CREEK IMPROVEMENT DISTRICT'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'LRC WHITE CASTLE',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'REEDY CREEK GEN',
#    'REEDY CREEK RESID',
#    'REEDY CREEK THEME'],
#   'FTS': 'FTS-2'},
#  {'Names': ['TALLAHASSEE, CITY OF'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST LANDRY',
#    'LRC WHITE CASTLE',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'SNG ANR-SHADYSIDE',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'LAKE WORTH SOUTH-FPU',
#    'LAKELAND MCINTOSH',
#    'SNG FRANKLINTON BI-DIR (DEL)',
#    'TALLAHASSEE SOUTH',
#    'TALLAHASSEE-ST MARKS(PURDOM)',
#    'TALLAHASSEE-W (HOPKINS)'],
#   'FTS': 'FTS-2'},
#  {'Names': ['POLK POWER PARTNERS, L.P.',
#    'RAINBOW ENERGY MARKETING CORPORATION'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'SABINE PASS PLANT',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TX GAS EUNICE',
#    'BARTOW-POLK POWER PARTNERS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY', 'RADIATE ENERGY LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TX GAS EUNICE',
#    'DELAND DIVISION',
#    'FORT MEADE',
#    'INDIANTOWN',
#    'NEW SMYRNA-FPU',
#    'PLANT CITY DIVISION',
#    'SANFORD DIVISION',
#    'WEST PALM BEACH DIVISION',
#    'WINTER HAVEN DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'BELVEDERE - FPU',
#    'BOCA RATON-FPU',
#    'BOYNTON CTG-FPU',
#    'DELAND DIVISION',
#    'DELAND SOUTH-FPU',
#    'DELAND-FPU',
#    'DELRAY-FPU',
#    'INDIANTOWN',
#    'LAKE WORTH SOUTH-FPU',
#    'LAKE WORTH-FPU',
#    'RIVIERA BEACH NORTH-FPU',
#    'SANFORD DIVISION',
#    'SANFORD W-FPU',
#    'SANFORD-FPU',
#    'W PALM BEACH W-FPU',
#    'W PALM BEACH-FPU',
#    'WEST PALM BEACH DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'SABINE PASS PLANT',
#    'NEW SMYRNA-FPU'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG FRANKLINTON (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'FORT MEADE'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TX GAS EUNICE',
#    'AUBURNDALE-CUC',
#    'BARTOW A-CUC',
#    'BARTOW B-CUC',
#    'LAKE MATTIE-CUC',
#    'LAKE WALES EAST-CUC',
#    'LAKE WALES-CUC',
#    'PIERCE-CUC',
#    'PLANT CITY DIVISION',
#    'PLANT CITY-CUC',
#    'POLK CORRECTIONAL INSTITUTION-CUC',
#    'WINTER HAVEN DIVISION',
#    'WINTER HAVEN-CUC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LAKELAND, CITY OF'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST HELENA',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TEJAS CALHOUN CO ITE',
#    'TX GAS EUNICE',
#    'LAKELAND GENERATING',
#    'LAKELAND MCINTOSH'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'EGAN HUB (REC)',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRUNKLINE VERMILION',
#    'COCOA DIVISION',
#    'COCOA-CITY GAS',
#    'CUTLER RIDGE DIVISION',
#    'CUTLER RIDGE-NUI CITY GAS',
#    'EAU GALLIE-CITY GAS (COCOA)',
#    'HIALEAH DIVISION',
#    'INDIAN RIVER-PPC',
#    'LAKE FOREST-CITY GAS',
#    'MELBOURNE DIVISION',
#    'MELBOURNE-CITY GAS',
#    'MIAMI AIRPORT-FCG',
#    'NW 16TH GATE STATION CTG-NUI',
#    'NW HIALEAH-CITY GAS',
#    'OPA LOCKA-CITY GAS',
#    'PALM BAY CTG-NUI',
#    'PIONEER GATE-NUI',
#    'PORT ST LUCIE-CITY GAS',
#    'SE HIALEAH-CITY GAS',
#    'SOUTH MIAMI-CITY GAS',
#    'ST. LUCIE DIVISION',
#    'SW-CITY GAS',
#    'TITUSVILLE DIVISION',
#    'TITUSVILLE-CITY GAS',
#    'VERO BEACH NORTH-CITY GAS',
#    'VERO BEACH SOUTH-CITY GAS',
#    'W MIAMI-CITY GAS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'EMERA ENERGY SERVICES, INC.'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GILLIS-TRUNKLINE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'MARKHAM-GULF SHORE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'TX GAS EUNICE',
#    'BAYSIDE-TECO',
#    'DAYTONA BEACH DIVISION',
#    'E PALATKA-PGS',
#    'EUSTIS DIVISION',
#    'FISHHAWK-PGS/TECO',
#    'GEORGIA PACIFIC',
#    'HIGHLANDS DIVISION',
#    'HUDSON-TECO/PGS',
#    'JACKSONVILLE DIVISION',
#    'LAKE BLUE DIVISION',
#    'LAKELAND DIVISION',
#    'OAK GROVE-PGS',
#    'OCALA DIVISION',
#    'ORLANDO DIVISION',
#    'PALM BEACH DIVISION',
#    'PANAMA CITY DIVISION',
#    'POLK POWER STATION-TECO',
#    'PUTNAM HALL - SEACOAST',
#    'SARASOTA DIVISION',
#    'SOUTH FLORIDA DIVISION',
#    'ST. PETERSBURG DIVISION',
#    'TAMPA DIVISION',
#    'TREASURE COAST DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'JACKSONVILLE DIVISION',
#    'JACKSONVILLE-PGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'MIAMI BEACH-PGS',
#    'MIAMI-PGS',
#    'SOUTH FLORIDA DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GILLIS-TRUNKLINE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'MARKHAM-GULF SHORE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'TX GAS EUNICE',
#    'AVON PARK-PGS',
#    'BAYSIDE-TECO',
#    'BRANDON-PGS',
#    'CECIL FIELD-PGS',
#    'CEDAR HILLS-PGS',
#    'COCONUT CREEK-PGS',
#    'DANIA-PGS',
#    'DAYTONA BEACH DIVISION',
#    'DAYTONA BEACH-PGS',
#    'E PALATKA-PGS',
#    'EUSTIS DIVISION',
#    'EUSTIS NORTH-PGS',
#    'EUSTIS-PGS',
#    'FISHHAWK-PGS/TECO',
#    'FROSTPROOF-PGS',
#    'GEORGIA PACIFIC',
#    'HIGHLANDS DIVISION',
#    'HUDSON-TECO/PGS',
#    'JACKSONVILLE DIVISION',
#    'JACKSONVILLE-PGS',
#    'LAKE BLUE DIVISION',
#    'LAKE BLUE-TECO/PGS',
#    'LAKE MURPHY-TECO/PGS',
#    'LAKELAND DIVISION',
#    'LAKELAND NORTH-PGS',
#    'LAKELAND-PGS',
#    'MIAMI BEACH-PGS',
#    'MIAMI-PGS',
#    'MT DORA-PGS',
#    'NORTH MIAMI-PGS',
#    'OAK GROVE-PGS',
#    'OCALA DIVISION',
#    'OCALA NORTH-TECO/PGS',
#    'OCALA-PGS',
#    'ONECO-TECO/PGS',
#    'ORLANDO DIVISION',
#    'ORLANDO E-PGS',
#    'ORLANDO NORTH-PGS',
#    'ORLANDO SOUTH-PGS',
#    'ORLANDO SW-PGS',
#    'ORLANDO TURNPIKE-TECO/PGS',
#    'ORLANDO W-PGS',
#    'ORLANDO-PGS',
#    'OSCEOLA CO-PGS',
#    'PALM BEACH DIVISION',
#    'PALM BEACH-TECO/PGS',
#    'PANAMA CITY - PGS',
#    'PANAMA CITY DIVISION',
#    'PLANTATION-PGS',
#    'POLK POWER STATION-TECO',
#    'PUTNAM HALL - SEACOAST',
#    'SARASOTA DIVISION',
#    'SEBRING-PGS',
#    'SILVER SPRINGS-TECO/PGS',
#    'SOUTH FLORIDA DIVISION',
#    'ST PETERSBURG NORTH-PGS',
#    'ST PETERSBURG-PGS',
#    'ST. PETERSBURG DIVISION',
#    'TAMPA DIVISION',
#    'TAMPA E-PGS',
#    'TAMPA NORTH-PGS',
#    'TAMPA NW-TECO/PGS',
#    'TAMPA SOUTH-PGS',
#    'TAMPA W-PGS',
#    'TREASURE COAST DIVISION',
#    'TREASURE COAST ENERGY CENTER',
#    'UMATILLA-PGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['MOSAIC FERTILIZER, LLC', 'GAS SOUTH, LLC'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'MARKHAM-GULF SHORE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TAMPA-MOSAIC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['UNITED TECHNOLOGIES, PRATT & WHITNEY', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST LANDRY',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'PRATT &  WHITNEY'],
#   'FTS': ''},
#  {'Names': ['TALLAHASSEE, CITY OF', 'RADIATE ENERGY LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'LRC KAPLAN',
#    'MARKHAM-GULF SHORE',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PINE PRAIRIE STORAGE (REC)',
#    'REFUGIO-CROSSTEX ENERGY',
#    'ROBSTOWN-PANENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'BARTOW-MOSAIC',
#    'BUCKEYE CELLULOSE',
#    'CS #8 ZACHARY ZONE 2',
#    'LAKELAND MCINTOSH',
#    'LAUDERDALE B-FPL',
#    'MARTIN-FPL',
#    'PALM CITY FLOW',
#    'TALLAHASSEE HOPKINS #2',
#    'TALLAHASSEE SOUTH',
#    'TALLAHASSEE-ST MARKS(PURDOM)',
#    'TALLAHASSEE-W (HOPKINS)',
#    'TAMPA-MOSAIC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['STATE OF FLORIDA, DEPARTMENT OF MANAGEME', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'MADISON',
#    'NW HIALEAH-CITY GAS',
#    'POLK CORRECTIONAL INSTITUTION-CUC',
#    'RAIFORD STATE PRISON'],
#   'FTS': 'FTS-1'},
#  {'Names': ['GEORGIA-PACIFIC LLC', 'KOCH ENERGY SERVICES, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'SABINE PASS PLANT',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TX GAS EUNICE',
#    'GEORGIA PACIFIC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ST. JOE NATURAL GAS COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ST JOE NATURAL GAS',
#    'ST. JOE OVERSTREET'],
#   'FTS': 'FTS-1'},
#  {'Names': ['REEDY CREEK IMPROVEMENT DISTRICT'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRUNKLINE VERMILION',
#    'GENERATING DIVISION',
#    'REEDY CREEK GEN',
#    'REEDY CREEK RESID',
#    'REEDY CREEK THEME',
#    'RESIDENTIAL DIVISION',
#    'THEME PARK DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA GAS UTILITY', 'GAS SOUTH, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'HPL TEXOMA (REC)',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'BLOUNTSTOWN',
#    'CHIPLEY',
#    'CLEARWATER DIVISION',
#    'CRESCENT CITY',
#    'DEFUNIAK SPRINGS',
#    'FORT PIERCE LDC DIVISION',
#    'HOMESTEAD GENERATING #2',
#    'KISSIMMEE CANE ISLAND',
#    'LAKE CITY',
#    'LEESBURG DIVISION',
#    'LIVE OAK',
#    'MARIANNA',
#    'PALATKA2 DIVISION',
#    'STARKE',
#    'SUNRISE',
#    'TREASURE COAST ENERGY CENTER',
#    'W LAKE WORTH CTG-FGU',
#    'WILLISTON DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['SUNRISE, CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'PLEDGER-ENTERPRISE',
#    'TENN CARNES (REC)',
#    'SUNRISE'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CRESCENT CITY NATURAL GAS', 'FLORIDA GAS UTILITY'],
#   'Locations': ['REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'CRESCENT CITY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['SUNRISE, CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TENN CARNES (REC)',
#    'TRANSCO ST HELENA',
#    'TRUNKLINE MANCHESTER',
#    'SUNRISE'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LAKE CITY, CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'LAKE CITY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LIVE OAK, CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'LIVE OAK'],
#   'FTS': 'FTS-1'},
#  {'Names': ['MARIANNA, CITY OF'],
#   'Locations': ['GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'MARIANNA'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PALATKA GAS AUTHORITY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'PALATKA GAS-E PALATKA',
#    'PALATKA GAS-PALATKA',
#    'PALATKA2 DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['WILLISTON,  CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'SNG FRANKLINTON (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'CITY OF WILLISTON SOUTH',
#    'WILLISTON',
#    'WILLISTON DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'PLEDGER-ENTERPRISE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'KISSIMMEE CANE ISLAND',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CITY OF HOMESTEAD', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'HOMESTEAD GENERATING #2'],
#   'FTS': 'FTS-1'},
#  {'Names': ['KISSIMMEE UTILITY AUTHORITY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'KISSIMMEE CANE ISLAND'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CITY OF CLEARWATER', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'CLEARWATER DIVISION',
#    'CLEARWATER EAST',
#    'CLEARWATER NORTH',
#    'CLEARWATER SOUTH',
#    'CLEARWATER TRINITY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FORT PIERCE LDC', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'FORT PIERCE LDC DIVISION',
#    'FT PIERCE NORTH',
#    'FT PIERCE SOUTH'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CITY OF LEESBURG', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO ST HELENA',
#    'LEESBURG',
#    'LEESBURG DIVISION',
#    'LEESBURG-HAINES CREEK'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CITY OF STARKE', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'STARKE'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'PLEDGER-ENTERPRISE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'TRUNKLINE MANCHESTER',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DEFUNIAK SPRINGS, CITY OF', 'FLORIDA GAS UTILITY'],
#   'Locations': ['GSPL ST HELENA',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'DEFUNIAK SPRINGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['BLOUNTSTOWN, CITY OF'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG FRANKLINTON (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'BLOUNTSTOWN'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CHIPLEY, CITY OF'],
#   'Locations': ['GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'CHIPLEY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CITY OF LAKE WORTH BEACH', 'FLORIDA GAS UTILITY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'W LAKE WORTH CTG-FGU'],
#   'FTS': 'FTS-1'},
#  {'Names': ['FLORIDA MUNICIPAL POWER AGENCY'],
#   'Locations': ['GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG HIGH POINT-TOCA',
#    'SNG KOCH-SHADYSIDE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'STARKE',
#    'TREASURE COAST ENERGY CENTER'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['BOURBON LINE FROM MS CANYON 268',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'MAGNET WITHERS-ENTERPRISE',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'SABINE-KAPLAN',
#    'SNG HIGH POINT-TOCA',
#    'TIGER BAY-FPC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST LANDRY',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO VINTON',
#    'OCALA DIVISION',
#    'OCALA-PGS',
#    'PANAMA CITY - PGS',
#    'PANAMA CITY DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'EMERA ENERGY SERVICES, INC.'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GSPL ST LANDRY',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO VINTON',
#    'TRES PALACIOS STORAGE (REC)',
#    'TX GAS EUNICE',
#    'DAYTONA BEACH DIVISION',
#    'FT MYERS DIVISION-PGS',
#    'HIGHLANDS DIVISION',
#    'JACKSONVILLE DIVISION',
#    'LAKELAND DIVISION',
#    'OCALA DIVISION',
#    'ORLANDO DIVISION',
#    'PALM BEACH DIVISION',
#    'PANAMA CITY DIVISION',
#    'SARASOTA DIVISION',
#    'SOUTH FLORIDA DIVISION',
#    'TAMPA DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'FT MYERS CTG-PGS',
#    'FT MYERS DIVISION-PGS',
#    'HIGHLANDS DIVISION',
#    'LAKELAND DIVISION',
#    'LAKELAND NORTH-PGS',
#    'LAKEWOOD RANCH-TECO/PGS',
#    'ONECO-TECO/PGS',
#    'SARASOTA DIVISION',
#    'SEBRING-PGS',
#    'TAMPA DIVISION',
#    'TAMPA NORTH-PGS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'NGPL VERMILION',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'AVON PARK-PGS',
#    'FT MYERS CTG-PGS',
#    'FT MYERS DIVISION-PGS',
#    'HIGHLANDS DIVISION',
#    'LAKEWOOD RANCH-TECO/PGS',
#    'SARASOTA DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'NGPL VERMILION',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'LAKEWOOD RANCH-TECO/PGS',
#    'SARASOTA DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'GSPL ST LANDRY',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRES PALACIOS STORAGE (REC)',
#    'TX GAS EUNICE',
#    'DAYTONA BEACH DIVISION',
#    'DAYTONA BEACH-PGS',
#    'JACKSONVILLE DIVISION',
#    'JACKSONVILLE-PGS',
#    'LAKEWOOD RANCH-TECO/PGS',
#    'NORTH MIAMI-PGS',
#    'ONECO-TECO/PGS',
#    'ORLANDO DIVISION',
#    'ORLANDO SOUTH-PGS',
#    'ORLANDO SW-PGS',
#    'ORLANDO TURNPIKE-TECO/PGS',
#    'ORLANDO W-PGS',
#    'ORLANDO-PGS',
#    'PALM BEACH DIVISION',
#    'PALM BEACH-TECO/PGS',
#    'SARASOTA DIVISION',
#    'SOUTH FLORIDA DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['MOSAIC FERTILIZER, LLC', 'GAS SOUTH, LLC'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'MARKHAM-GULF SHORE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'BARTOW-MOSAIC',
#    'CRESCENT CITY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['NFH  MANAGEMENT CORPORATION'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'PLEDGER-ENTERPRISE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'NORTH FLORIDA HOLSTEINS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['JEA'],
#   'Locations': ['HPL MAGNET WITHERS', 'JACKSONVILLE-PGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['JEA', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'JACKSONVILLE-PGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['JEA', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'NGPL VERMILION',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'JACKSONVILLE-PGS'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ORANGE COGENERATION LIMITED PARTNERSHIP',
#    'RAINBOW ENERGY MARKETING CORPORATION'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST LANDRY',
#    'NGPL JEFFERSON',
#    'SABINE PASS PLANT',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TX GAS EUNICE',
#    'BARTOW B-CUC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['POWERSOUTH ENERGY COOPERATIVE'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'ALABAMA ELECTRIC CO-OP'],
#   'FTS': ''},
#  {'Names': ['MOSAIC FERTILIZER, LLC', 'GAS SOUTH, LLC'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'BARTOW-MOSAIC',
#    'TAMPA-MOSAIC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['STATE OF FLORIDA, DEPARTMENT OF MANAGEME', 'GAS SOUTH, LLC'],
#   'Locations': ['NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ST. JOE OVERSTREET'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CENTERPOINT ENERGY RESOURCES CORP. DBA CENTERPOINT ENERGY ENTEX'],
#   'Locations': ['CS #7 EUNICE ZONE 1',
#    'MARKHAM-GULF SHORE',
#    'PAN AMERICAN ENTEX',
#    'RAMSEY ENTEX'],
#   'FTS': ''},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['AMOCO-JUDGE DIGBY',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'LRC WHITE CASTLE',
#    'REFUGIO-CROSSTEX ENERGY',
#    'ROBSTOWN-PANENERGY',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'INDIAN RIVER CTG-RELIANT',
#    'INDIAN RIVER-OUC',
#    'STANTON-OUC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CLARKE-MOBILE COUNTIES GAS DISTRICT'],
#   'Locations': ['DESTIN P/L',
#    'CLARKE-MOBILE/MT VERNON TBS A',
#    'ENERFIN CLARKE-MOBILE (DEL)'],
#   'FTS': ''},
#  {'Names': ['LAKELAND, CITY OF'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'LRC KAPLAN',
#    'PEARL RIVER',
#    'TRANSCO ST HELENA',
#    'CS #7 EUNICE ZONE 1',
#    'GAINESVILLE DIVISION',
#    'GAINESVILLE GAS-NORTH',
#    'GAINESVILLE GAS-PLT',
#    'GAINESVILLE GAS-UNIVERSITY',
#    'GAINESVILLE GAS-WEST',
#    'GAINESVILLE GENERATING',
#    'GAINESVILLE-DEERHAVEN GEN',
#    'LAKELAND GENERATING',
#    'LAKELAND MCINTOSH',
#    'LAKELAND-MCINTOSH DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LAKELAND, CITY OF'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #8 ZACHARY ZONE 2',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'TRANSCO ST HELENA',
#    'GAINESVILLE DIVISION',
#    'GAINESVILLE GAS-NORTH',
#    'GAINESVILLE GAS-PLT',
#    'GAINESVILLE GAS-UNIVERSITY',
#    'GAINESVILLE GAS-WEST',
#    'GAINESVILLE GENERATING',
#    'GAINESVILLE-DEERHAVEN GEN',
#    'LAKELAND GENERATING',
#    'LAKELAND MCINTOSH',
#    'LAKELAND-MCINTOSH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'DESTIN P/L',
#    'LRC KAPLAN',
#    'MAGNET WITHERS-ENTERPRISE',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'GAINESVILLE UNIVERSITY COGEN',
#    'HINES ENERGY COMPLEX-FPC',
#    'TIGER BAY-FPC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'CS #8 ZACHARY ZONE 2',
#    'DESTIN P/L',
#    'MAGNET WITHERS-ENTERPRISE',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ANCLOTE-FPC',
#    'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['GAINESVILLE REGIONAL UTILITIES', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COGNAC LINE (TGPL) FROM MS CANYON 1',
#    'COLUMBIA GULF-LAFAYETTE',
#    'EGAN HUB (REC)',
#    'EGP COW ISLAND PLT OUTLET',
#    'FRISCO ACADIAN',
#    'HPL MAGNET WITHERS',
#    'HPL TEXOMA (REC)',
#    'MARKHAM-GULF SHORE',
#    'MATAGORDA 687/699',
#    'MOPS-REFUGIO',
#    'MUSTANG 758 SUB-SEA IC',
#    'MUSTANG 759/738 SS I/C',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG KOCH-SHADYSIDE',
#    'TEJAS CALHOUN CO ITE',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO MUSTANG 757/762',
#    'CS #11 MT VERNON ZONE 3',
#    'CS #7 EUNICE ZONE 1',
#    'GAINESVILLE DIVISION',
#    'GAINESVILLE GAS-NORTH',
#    'GAINESVILLE GAS-PLT',
#    'GAINESVILLE GAS-UNIVERSITY',
#    'GAINESVILLE GAS-WEST',
#    'GAINESVILLE GENERATING',
#    'GAINESVILLE-DEERHAVEN GEN',
#    'SHANDS HOSPITAL-GRU'],
#   'FTS': 'FTS-1'},
#  {'Names': ['GAINESVILLE REGIONAL UTILITIES', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['COGNAC LINE (TGPL) FROM MS CANYON 1',
#    'COLUMBIA GULF-LAFAYETTE',
#    'ENBRIDGE-ORANGE CO',
#    'FRISCO ACADIAN',
#    'HPL MAGNET WITHERS',
#    'HPL TEXOMA (REC)',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SNG KOCH-SHADYSIDE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'GAINESVILLE DIVISION',
#    'GAINESVILLE GAS-NORTH',
#    'GAINESVILLE GAS-PLT',
#    'GAINESVILLE GAS-UNIVERSITY',
#    'GAINESVILLE GAS-WEST',
#    'GAINESVILLE GENERATING',
#    'GAINESVILLE-DEERHAVEN GEN',
#    'SHANDS HOSPITAL-GRU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ANCLOTE-FPC',
#    'FPC & KISSIMMEE DIVISION',
#    'HINES ENERGY COMPLEX-FPC',
#    'KISSIMMEE CANE ISLAND'],
#   'FTS': 'FTS-2'},
#  {'Names': ['GEORGIA-PACIFIC LLC', 'KOCH ENERGY SERVICES, LLC'],
#   'Locations': ['GSPL ST LANDRY',
#    'NGPL VERMILION',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'GEORGIA PACIFIC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['SOUTHERN COMPANY SERVICES, INC.'],
#   'Locations': ['DESTIN P/L',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'BAY GAS (DEL) STORAGE'],
#   'FTS': ''},
#  {'Names': ['POWERSOUTH ENERGY COOPERATIVE'],
#   'Locations': ['DESTIN P/L',
#    'GSPL MERRILL',
#    'GSPL ST HELENA',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'TRANSCO ST HELENA',
#    'ALABAMA ELECTRIC CO-OP'],
#   'FTS': ''},
#  {'Names': ['CITY OF MADISON', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'MOPS-REFUGIO',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'MADISON'],
#   'FTS': 'FTS-1'},
#  {'Names': ['JEA', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['DESTIN P/L',
#    'GSPL MOBILE BAY-FGT CAPACITY',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'BRANDY BRANCH-PGS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'EMERA ENERGY SERVICES, INC.'],
#   'Locations': ['DESTIN P/L', 'DAYTONA BEACH DIVISION', 'DAYTONA BEACH-PGS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['TALLAHASSEE, CITY OF'],
#   'Locations': ['GSPL MOBILE BAY-FGT CAPACITY',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'TALLAHASSEE-ST MARKS(PURDOM)',
#    'TALLAHASSEE-W (HOPKINS)'],
#   'FTS': 'FTS-2'},
#  {'Names': ['THE SOUTHEAST ALABAMA GAS DISTRICT',
#    'SOUTHEAST GAS ACQUISITION & SUPPLY'],
#   'Locations': ['TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'ALABAMA ELECTRIC CO-OP'],
#   'FTS': ''},
#  {'Names': ['TAMPA ELECTRIC COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'EGAN HUB (REC)',
#    'FRISCO ACADIAN',
#    'GSPL MOBILE BAY-FGT CAPACITY',
#    'GSPL MOBILE BAY-GULF SOUTH CAPACITY',
#    'GSPL ST HELENA',
#    'HPL MAGNET WITHERS',
#    'MOPS-REFUGIO',
#    'NAPOLEONVILLE STORAGE (REC)',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TEJAS CALHOUN CO ITE',
#    'TRUNKLINE MANCHESTER',
#    'BAYSIDE-TECO',
#    'HARDEE POWER PARTNERS METER STATION',
#    'POLK POWER STATION-TECO'],
#   'FTS': 'FTS-2'},
#  {'Names': ['LAKE APOPKA NATURAL GAS DISTRICT', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST LANDRY',
#    'MOPS-REFUGIO',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TENN CARNES (REC)',
#    'LAKE APOPKA DIVISION',
#    'LAKE APOPKA-APOPKA',
#    'LAKE APOPKA-KELLY PARK DELIVERY',
#    'LAKE APOPKA-PLYMOUTH',
#    'LAKE APOPKA-WINTER GARDEN',
#    'LANG WOODSMERE',
#    'PLYMOUTH DIVISION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LAKE APOPKA NATURAL GAS DISTRICT', 'GAS SOUTH, LLC'],
#   'Locations': ['BAY GAS (REC) STORAGE',
#    'ESCAMBIA CREEK',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'LRC WHITE CASTLE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SABINE PASS PLANT',
#    'ST REGIS',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'LAKE APOPKA DIVISION',
#    'LAKE APOPKA-APOPKA',
#    'LAKE APOPKA-KELLY PARK DELIVERY',
#    'LAKE APOPKA-PLYMOUTH',
#    'LAKE APOPKA-WINTER GARDEN',
#    'LANG WOODSMERE',
#    'NATIONAL GYPSUM COMPANY',
#    'NATIONAL GYPSUM DIVISION-ADMIN',
#    'PLYMOUTH DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['TENN CARNES (REC)',
#    'HARDEE POWER PARTNERS METER STATION',
#    'HINES ENERGY COMPLEX-FPC',
#    'MIDULLA GENERATION STATION'],
#   'FTS': 'FTS-1'},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.', 'RADIATE ENERGY LLC'],
#   'Locations': ['DESTIN P/L',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'HARDEE POWER PARTNERS METER STATION',
#    'HINES ENERGY COMPLEX-FPC',
#    'MIDULLA GENERATION STATION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['NATIONAL GYPSUM COMPANY', 'GAS SOUTH, LLC'],
#   'Locations': ['LRC WHITE CASTLE',
#    'NGPL VERMILION',
#    'NATIONAL GYPSUM COMPANY'],
#   'FTS': 'FTS-2'},
#  {'Names': ['TAMPA ELECTRIC COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'NGPL VERMILION',
#    'BAYSIDE-TECO'],
#   'FTS': 'FTS-1'},
#  {'Names': ['TAMPA ELECTRIC COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'GSPL ST HELENA',
#    'NGPL VERMILION',
#    'BAYSIDE-TECO'],
#   'FTS': 'FTS-1'},
#  {'Names': ['TAMPA ELECTRIC COMPANY'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE', 'GSPL ST HELENA', 'BAYSIDE-TECO'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['AMOCO-JUDGE DIGBY',
#    'ANR ST LANDRY PARISH',
#    'BAY GAS (REC) STORAGE',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'LRC KAPLAN',
#    'LRC WHITE CASTLE',
#    'MOPS-REFUGIO',
#    'NAPOLEONVILLE STORAGE (REC)',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG CYPRESS',
#    'SNG FRANKLINTON (REC)',
#    'TEJAS CALHOUN CO ITE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'INDIAN RIVER-OUC',
# ...
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'TRUNKLINE VERMILION',
#    'AUBURNDALE-CUC',
#    'BARTOW A-CUC',
#    'HAINES CITY-CUC',
#    'HINES ENERGY COMPLEX-FPC',
#    'INDIANTOWN',
#    'LAKE ALFRED-CUC',
#    'PLANT CITY DIVISION',
#    'PLANT CITY-CUC',
#    'WINTER HAVEN DIVISION',
#    'WINTER HAVEN-CUC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC',
#    'GAS SOUTH, LLC',
#    'SPOTLIGHT ENERGY, LLC'],
#   'Locations': ['TRANSCO CITRONELLE FGT MAINLINE',
#    'ANCLOTE-FPC',
#    'EL PASO VANDOLAH',
#    'HINES ENERGY COMPLEX-FPC',
#    'SHADY HILLS-MIRANT',
#    'SUWANNEE-PROGRESS ENERGY'],
#   'FTS': ''},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['GSPL MERRILL',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'CAPE CANAVERAL-FPL',
#    'CUTLER-FPL',
#    'E PALATKA-FPL',
#    'FT MYERS-FPL',
#    'LAUDERDALE A-FPL',
#    'LAUDERDALE B-FPL',
#    'MANATEE-FPL',
#    'MARTIN-FPL',
#    'PORT EVERGLADES ENERGY CENTER M&R-F',
#    'PORT EVERGLADES-FPL',
#    'PUTNAM-FPL',
#    'RIVIERA EAST-FPL',
#    'RIVIERA WEST-FPL',
#    'RIVIERA-FPL',
#    'SANFORD-FPL',
#    'TURKEY POINT NORTH-FPL',
#    'TURKEY PT-FPL'],
#   'FTS': ''},
#  {'Names': ['TAMPA ELECTRIC COMPANY'],
#   'Locations': ['SESH LUCEDALE (REC)',
#    'SESH MOBILE BAY',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'BAYSIDE-TECO',
#    'DESOTO CO GENERATION (DEL)',
#    'LAKELAND NORTH-PGS',
#    'POLK POWER STATION-TECO'],
#   'FTS': ''},
#  {'Names': ['TALLAHASSEE, CITY OF', 'J. ARON & COMPANY'],
#   'Locations': ['SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'TALLAHASSEE HOPKINS #2'],
#   'FTS': ''},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['DESTIN P/L',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'STANTON B-OUC',
#    'STANTON-OUC',
#    'VERO BEACH GENERATING'],
#   'FTS': ''},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['DESTIN P/L',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'HARDEE POWER PARTNERS METER STATION',
#    'MIDULLA GENERATION STATION',
#    'PUTNAM HALL - SEACOAST'],
#   'FTS': ''},
#  {'Names': ['OKALOOSA GAS DISTRICT', 'GAS SOUTH, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRANSCO ST HELENA',
#    'OKALOOSA CO',
#    'OKALOOSA DIVISION'],
#   'FTS': ''},
#  {'Names': ['OKALOOSA GAS DISTRICT', 'GAS SOUTH, LLC'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'GSPL ST LANDRY',
#    'MOPS-REFUGIO',
#    'NGPL JEFFERSON',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'TRANSCO ST HELENA',
#    'OKALOOSA CO',
#    'OKALOOSA DIVISION',
#    'WALTON OKALOOSA'],
#   'FTS': ''},
#  {'Names': ['CHATTAHOOCHEE, CITY OF', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'MOPS-REFUGIO',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'CHATTAHOOCHEE'],
#   'FTS': 'FTS-1'},
#  {'Names': ['GENEVA COUNTY GAS DISTRICT', 'GAS SOUTH, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'MOPS-REFUGIO',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'GENEVA CO GAS DISTRICT'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ANGOLA LNG SUPPLY SERVICES, LLC'],
#   'Locations': ['GULF LNG PASCAGOULA',
#    'GRAND BAY (DEL)',
#    'GULF LNG CITRONELLE',
#    'SOUTHERN PINES STORAGE (DEL)'],
#   'FTS': ''},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['GSPL ST HELENA',
#    'MAGNET WITHERS-ENTERPRISE',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TENN CARNES (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'CHATTAHOOCHEE',
#    'FLORALA',
#    'GENEVA CO GAS DISTRICT',
#    'SUWANNEE-PROGRESS ENERGY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['CUTRALE CITRUS JUICES USA, INC.',
#    'BP ENERGY COMPANY',
#    'PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'EMERA ENERGY SERVICES, INC.'],
#   'Locations': ['DESTIN P/L',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'INDIAN RIVER CTG-RELIANT',
#    'OLEANDER POWER CT'],
#   'FTS': 'FTS-1'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['DESTIN P/L',
#    'EGAN HUB (REC)',
#    'TRANSCO ST HELENA',
#    'CUTLER RIDGE DIVISION',
#    'CUTLER RIDGE-NUI CITY GAS',
#    'HIALEAH DIVISION',
#    'INDIAN RIVER-CITY GAS',
#    'LAKE FOREST-CITY GAS',
#    'MELBOURNE DIVISION',
#    'MELBOURNE-CITY GAS',
#    'NW HIALEAH-CITY GAS',
#    'OPA LOCKA-CITY GAS',
#    'SE HIALEAH-CITY GAS',
#    'SOUTH MIAMI-CITY GAS',
#    'TITUSVILLE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['DESTIN P/L',
#    'NGPL JEFFERSON',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'COCOA DIVISION',
#    'COCOA-CITY GAS',
#    'CUTLER RIDGE DIVISION',
#    'CUTLER RIDGE-NUI CITY GAS',
#    'EAU GALLIE-CITY GAS (COCOA)',
#    'HIALEAH DIVISION',
#    'INDIAN RIVER-CITY GAS',
#    'LAKE FOREST-CITY GAS',
#    'NW HIALEAH-CITY GAS',
#    'OPA LOCKA-CITY GAS',
#    'PORT ST LUCIE-CITY GAS',
#    'SE HIALEAH-CITY GAS',
#    'SOUTH MIAMI-CITY GAS',
#    'ST. LUCIE DIVISION',
#    'TITUSVILLE DIVISION',
#    'VERO BEACH NORTH-CITY GAS',
#    'VERO BEACH SOUTH-CITY GAS',
#    'W MIAMI-CITY GAS'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['DESTIN P/L',
#    'FRISCO ACADIAN',
#    'COCOA DIVISION',
#    'COCOA-CITY GAS',
#    'MELBOURNE DIVISION',
#    'MELBOURNE-CITY GAS',
#    'PORT ST LUCIE-CITY GAS',
#    'ST. LUCIE DIVISION',
#    'VERO BEACH NORTH-CITY GAS',
#    'VERO BEACH SOUTH-CITY GAS',
#    'VIERA-NUI'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['DESTIN P/L',
#    'EGAN HUB (REC)',
#    'FRISCO ACADIAN',
#    'LRC WHITE CASTLE',
#    'NGPL JEFFERSON',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'TRANSCO ST HELENA',
#    'COCOA DIVISION',
#    'CUTLER RIDGE DIVISION',
#    'HIALEAH DIVISION',
#    'MELBOURNE DIVISION',
#    'ST. LUCIE DIVISION',
#    'TITUSVILLE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['PIVOTAL UTILITY HOLDINGS, INC., D/B/A FL'],
#   'Locations': ['EGAN HUB (REC)',
#    'LRC WHITE CASTLE',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'INDIAN RIVER-CITY GAS',
#    'TITUSVILLE DIVISION'],
#   'FTS': 'FTS-2'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['NGPL VERMILION', 'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['NGPL VERMILION', 'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['EXXON PLANT-MOBILE BAY',
#    'MARKHAM-GULF SHORE',
#    'SABINE PASS PLANT',
#    'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['EXXON PLANT-MOBILE BAY',
#    'MARKHAM-GULF SHORE',
#    'SABINE PASS PLANT',
#    'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-2'},
#  {'Names': ['DUKE ENERGY FLORIDA, LLC'],
#   'Locations': ['EXXON PLANT-MOBILE BAY',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'HINES ENERGY COMPLEX-FPC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ORLANDO COGEN LIMITED, L.P.', 'BP ENERGY COMPANY'],
#   'Locations': ['DESTIN P/L',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SNG HIGH POINT-TOCA',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ORLANDO COGEN'],
#   'FTS': 'FTS-2'},
#  {'Names': ['ORLANDO COGEN LIMITED, L.P.', 'BP ENERGY COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'DESTIN P/L',
#    'MARKHAM-GULF SHORE',
#    'MOPS-REFUGIO',
#    'NGPL VERMILION',
#    'SNG HIGH POINT-TOCA',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'ORLANDO COGEN'],
#   'FTS': 'FTS-2'},
#  {'Names': ['OCI BEAUMONT, LLC'],
#   'Locations': ['PLEDGER-ENTERPRISE', 'BEAUMONT-OCI'],
#   'FTS': ''},
#  {'Names': ['ENTERPRISE PRODUCTS OPERATING LLC'],
#   'Locations': ['PLEDGER-ENTERPRISE', 'MCFADDEN BEND-ENTERPRISE'],
#   'FTS': ''},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'EMERA ENERGY SERVICES, INC.'],
#   'Locations': ['DESTIN P/L',
#    'GSPL MERRILL',
#    'SESH LUCEDALE (REC)',
#    'BAYSIDE-TECO',
#    'BRANDY BRANCH-PGS',
#    'FT MYERS CTG-PGS',
#    'K 117299 PT GROUP',
#    'LAKEWOOD RANCH-TECO/PGS',
#    'OSCEOLA CO-PGS',
#    'PALM BEACH-TECO/PGS',
#    'POLK POWER STATION-TECO',
#    'SEACOAST-TECO',
#    'SNG SUWANNEE'],
#   'FTS': ''},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA',
#    'PERRY, CITY OF',
#    'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'TENN CARNES (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'PERRY'],
#   'FTS': 'FTS-2'},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'DESTIN P/L',
#    'INDIAN RIVER CTG-RELIANT',
#    'RELIANT HOLOPAW',
#    'STANTON C GAS IGNITER CONVERSION-OU'],
#   'FTS': 'FTS-2'},
#  {'Names': ['CITY OF BREWTON, ALABAMA', 'BP ENERGY COMPANY'],
#   'Locations': ['DESTIN P/L', 'CITY OF BREWTON', 'GSPL FLOMATON'],
#   'FTS': ''},
#  {'Names': ['TOWN OF JAY', 'FLORIDA GAS UTILITY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST LANDRY',
#    'HPL MAGNET WITHERS',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SNG FRANKLINTON (REC)',
#    'TRES PALACIOS STORAGE (REC)',
#    'JAY'],
#   'FTS': ''},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'GSPL ST HELENA',
#    'MARKHAM-GULF SHORE',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE PASS PLANT',
#    'TRANSCO CITRONELLE FGT CAPACITY',
#    'BONIFAY CTG-CUC',
#    'BOYNTON CTG-FPU',
#    'CRYSTAL RIVER-CUC',
#    'LECANTO-CUC',
#    'SNEADS CTG-CUC',
#    'TRENTON-CUC',
#    'W PLANT CITY CFG',
#    'WASHINGTON CO-CFG'],
#   'FTS': 'FTS-2'},
#  {'Names': ['FLORIDA PUBLIC UTILITIES COMPANY', 'RADIATE ENERGY LLC'],
#   'Locations': ['DESTIN P/L',
#    'ARCADIA NW-CUC',
#    'BARTOW A-CUC',
#    'BONIFAY CTG-CUC',
#    'BREWSTER-FPU',
#    'CRYSTAL RIVER-CUC',
#    'LECANTO-CUC',
#    'OKEECHOBEE M&R STATION-FPU',
#    'QUINCY-CUC',
#    'RIVIERA WEST-FPL',
#    'SNEADS CTG-CUC',
#    'TRENTON-CUC',
#    'W PLANT CITY CFG'],
#   'FTS': ''},
#  {'Names': ['ASCEND PERFORMANCE MATERIALS INC.', 'BP ENERGY COMPANY'],
#   'Locations': ['DESTIN P/L', 'PENSACOLA - CUC'],
#   'FTS': ''},
#  {'Names': ['CITY OF PENSACOLA DBA PENSACOLA ENERGY', 'BP ENERGY COMPANY'],
#   'Locations': ['DESTIN P/L', 'PENSACOLA - CUC'],
#   'FTS': ''},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['DESTIN P/L',
#    'MIDULLA GENERATION STATION',
#    'PUTNAM HALL - SEACOAST'],
#   'FTS': ''},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['DESTIN P/L',
#    'MIDULLA GENERATION STATION',
#    'PUTNAM HALL - SEACOAST'],
#   'FTS': ''},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['DESTIN P/L',
#    'MIDULLA GENERATION STATION',
#    'PUTNAM HALL - SEACOAST'],
#   'FTS': ''},
#  {'Names': ['SHELL ENERGY NORTH AMERICA (US), L.P.'],
#   'Locations': ['EUNICE - ANR', 'GILLIS-TRUNKLINE', 'PORT ARTHUR-MOTIVA'],
#   'FTS': ''},
#  {'Names': ['POWERSOUTH ENERGY COOPERATIVE'],
#   'Locations': ['TRANSCO CITRONELLE FGT CAPACITY', 'ALABAMA ELECTRIC CO-OP'],
#   'FTS': ''},
#  {'Names': ['ASCEND PERFORMANCE MATERIALS INC.', 'BP ENERGY COMPANY'],
#   'Locations': ['DESTIN P/L', 'PENSACOLA - CUC'],
#   'FTS': ''},
#  {'Names': ['JERA ENERGY AMERICA LLC', 'EDF TRADING NORTH AMERICA, LLC'],
#   'Locations': ['COLUMBIA GULF-LAFAYETTE', 'WILSON-COASTAL BEND-FGT DEL'],
#   'FTS': ''},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.',
#    'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'],
#   'Locations': ['DESTIN P/L',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'BAYSIDE-TECO',
#    'PANAMA CITY - PGS',
#    'PANAMA CITY DIVISION',
#    'PANAMA CITY NORTH-TECO/PGS',
#    'PANAMA CITY-PGS',
#    'POLK POWER STATION-TECO',
#    'ST PETERSBURG NORTH-PGS',
#    'ST PETERSBURG-PGS',
#    'ST. PETERSBURG DIVISION'],
#   'FTS': ''},
#  {'Names': ['ENTERGY LOUISIANA, LLC'],
#   'Locations': ['TRANSCO CITRONELLE FGT MAINLINE',
#    'WASHINGTON PARISH - PWR PLT'],
#   'FTS': ''},
#  {'Names': ['TOPAZ GENERATING, LLC', 'MORGAN STANLEY CAPITAL GROUP, INC.'],
#   'Locations': ['TRES PALACIOS STORAGE (REC)', 'ATTWATER - TOPAZ'],
#   'FTS': ''},
#  {'Names': ['TOPAZ GENERATING, LLC', 'MORGAN STANLEY CAPITAL GROUP, INC.'],
#   'Locations': ['HPL TEXOMA (REC)', 'ATTWATER - TOPAZ'],
#   'FTS': ''},
#  {'Names': ['PEOPLES GAS SYSTEM, INC.'],
#   'Locations': ['DESTIN P/L',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'BAYSIDE-TECO',
#    'BIG BEND - PGS',
#    'OAK GROVE-PGS',
#    'TAMPA E-PGS',
#    'TAMPA NW-TECO/PGS'],
#   'FTS': ''},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['DESTIN P/L', 'CRIST - GULF POWER'],
#   'FTS': ''},
#  {'Names': ['CLARKE-MOBILE COUNTIES GAS DISTRICT'],
#   'Locations': ['DESTIN P/L', 'BAY GAS (DEL) STORAGE'],
#   'FTS': ''},
#  {'Names': ['CLARKE-MOBILE COUNTIES GAS DISTRICT'],
#   'Locations': ['DESTIN P/L',
#    'CLARKE-MOBILE DIVISION',
#    'CLARKE-MOBILE/MT VERNON TBS A',
#    'ENERFIN CLARKE-MOBILE (DEL)'],
#   'FTS': ''},
#  {'Names': ['SEMINOLE ELECTRIC COOPERATIVE, INC.'],
#   'Locations': ['HUNTERS CREEK-SABAL (REC)', 'PUTNAM HALL - SEACOAST'],
#   'FTS': ''},
#  {'Names': ['GAINESVILLE REGIONAL UTILITIES', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['SNG CYPRESS',
#    'GAINESVILLE DIVISION',
#    'GAINESVILLE GAS-NORTH',
#    'GAINESVILLE GAS-PLT',
#    'GAINESVILLE GAS-UNIVERSITY',
#    'GAINESVILLE GAS-WEST',
#    'GAINESVILLE GENERATING',
#    'GAINESVILLE-DEERHAVEN GEN',
#    'SHANDS HOSPITAL-GRU'],
#   'FTS': ''},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'COLUMBIA GULF-LAFAYETTE',
#    'DESTIN P/L',
#    'FRISCO ACADIAN',
#    'NGPL VERMILION',
#    'TRANSCO ST HELENA',
#    'INDIAN RIVER-OUC',
#    'STANTON-OUC'],
#   'FTS': 'FTS-1'},
#  {'Names': ['ORLANDO UTILITIES COMMISSION'],
#   'Locations': ['GSPL MERRILL',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT MAINLINE',
#    'STANTON B-OUC',
#    'STANTON C GAS IGNITER CONVERSION-OU'],
#   'FTS': 'FTS-1'},
#  {'Names': ['LAKELAND, CITY OF'],
#   'Locations': ['SOUTHERN PINES CITRONELLE STORAGE (', 'LAKELAND MCINTOSH'],
#   'FTS': ''},
#  {'Names': ['BROTMAN GENERATING, LLC', 'SPIRE MARKETING INC.'],
#   'Locations': ['TRES PALACIOS STORAGE (REC)', 'ROSHARON - BROTMAN'],
#   'FTS': ''},
#  {'Names': ['BROTMAN GENERATING, LLC', 'SPIRE MARKETING INC.'],
#   'Locations': ['HPL TEXOMA (REC)', 'ROSHARON - BROTMAN'],
#   'FTS': ''},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['SESH LUCEDALE (REC)', 'CRIST - GULF POWER'],
#   'FTS': ''},
#  {'Names': ['FLORIDA POWER & LIGHT COMPANY'],
#   'Locations': ['TRUNKLINE MANCHESTER',
#    'TRUNKLINE VERMILION',
#    'GSPL MOBILE BAY-FGT CAPACITY',
#    'SESH LUCEDALE (REC)',
#    'TRANSCO CITRONELLE FGT CAPACITY'],
#   'FTS': 'FTS-1'},
#  {'Names': ['GAS SOUTH, LLC'],
#   'Locations': ['GULFSTREAM HARDEE', 'CITRUS COUNTY - SABAL TRAIL'],
#   'FTS': 'FTS-1'},
#  {'Names': ['OKALOOSA GAS DISTRICT'],
#   'Locations': ['ANR ST LANDRY PARISH',
#    'NGPL VERMILION',
#    'REFUGIO-CROSSTEX ENERGY',
#    'SABINE-KAPLAN',
#    'SNG FRANKLINTON (REC)',
#    'TETCO-ATCHAFALAYA (REC)',
#    'FLORALA'],
#   'FTS': 'FTS-1'},
#  {'Names': ['BROTMAN II, LLC'],
#   'Locations': ['TRES PALACIOS STORAGE (REC)', 'ROSHARON - BROTMAN'],
#   'FTS': ''},
#  {'Names': ['BROTMAN II, LLC'],
#   'Locations': ['HPL TEXOMA (REC)', 'ROSHARON - BROTMAN'],
#   'FTS': ''},
#  {'Names': ['DENBURY ONSHORE, LLC', 'CONOCOPHILLIPS COMPANY'],
#   'Locations': ['PLEDGER-ENTERPRISE', 'DENBURY OYSTER BAYOU'],
#   'FTS': ''},
#  {'Names': ['JEA', 'THE ENERGY AUTHORITY, INC.'],
#   'Locations': ['SNG CYPRESS', 'BRANDY BRANCH-PGS'],
#   'FTS': 'FTS-1'}]

# %%
try:
    while True:
        
        print(f"-------------------------------Search--------------------------")
        
        location = str(input("Write the name you want to search for: "))
        fts = str(input("Enter the FTS number. (Leave empty if you want to see data for all FTS) "))

        location = location.upper()

        if fts:
            fts = fts[-1]

        for data in shipping_data:
            values = data['Locations']

            for i in values:
                if re.search(location, i, re.IGNORECASE):

                    if fts:
                        if fts == '1' and data['FTS'] == 'FTS-1':
                            print(f"{data['Names']} {i} {data['FTS']}")

                        elif fts == '2' and data['FTS'] == 'FTS-2':
                            print(f"{data['Names']} {i} {data['FTS']}")
                    else:
                        print(f"{data['Names']} {i} {data['FTS']}")

        choice = input("Enter e to end or press enter to continue: ")
        
        if choice == "e" or choice == "E":
            break
            
except KeyboardInterrupt:
    print("Operation interrupted by user")
except Exception as e:
    print("An error occurred: " + str(e))
# Out:
# -------------------------------Search--------------------------
# Write the name you want to search for: anr
# Enter the FTS number. (Leave empty if you want to see data for all FTS)
# ['FLORIDA GAS TRANSMISSION COMPANY, LLC', 'FLORIDA POWER & LIGHT COMPANY'] ANR ST LANDRY PARISH FTS-1
# ['FLORIDA POWER & LIGHT COMPANY'] ANR ST LANDRY PARISH FTS-2
# ['FLORIDA POWER & LIGHT COMPANY'] ANR ST LANDRY PARISH FTS-2
# ['FLORIDA MUNICIPAL POWER AGENCY'] ANR ST LANDRY PARISH FTS-2
# ['FLORIDA GAS UTILITY', 'LAKELAND, CITY OF', 'GAS SOUTH, LLC'] ANR ST LANDRY PARISH FTS-2
# ['KISSIMMEE UTILITY AUTHORITY', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-2
# ['CITY OF CLEARWATER', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-2
# ['CITY OF LEESBURG', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-2
# ['TALLAHASSEE, CITY OF'] SNG ANR-SHADYSIDE FTS-2
# ['FLORIDA PUBLIC UTILITIES COMPANY', 'RADIATE ENERGY LLC'] ANR ST LANDRY PARISH FTS-1
# ['FLORIDA PUBLIC UTILITIES COMPANY'] ANR ST LANDRY PARISH FTS-1
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA', 'EMERA ENERGY SERVICES, INC.'] ANR ST LANDRY PARISH FTS-1
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'] ANR ST LANDRY PARISH FTS-1
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'] ANR ST LANDRY PARISH FTS-1
# ['TALLAHASSEE, CITY OF', 'RADIATE ENERGY LLC'] ANR ST LANDRY PARISH FTS-1
# ['ST. JOE NATURAL GAS COMPANY'] ANR ST LANDRY PARISH FTS-1
# ['FLORIDA GAS UTILITY', 'GAS SOUTH, LLC'] ANR ST LANDRY PARISH FTS-1
# ['SUNRISE, CITY OF', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['SUNRISE, CITY OF', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['LIVE OAK, CITY OF', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['PALATKA GAS AUTHORITY', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['CITY OF CLEARWATER', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['CITY OF LEESBURG', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-1
# ['FLORIDA MUNICIPAL POWER AGENCY'] ANR ST LANDRY PARISH FTS-1
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'] ANR ST LANDRY PARISH FTS-2
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA', 'EMERA ENERGY SERVICES, INC.'] ANR ST LANDRY PARISH FTS-2
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'] ANR ST LANDRY PARISH FTS-2
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA'] ANR ST LANDRY PARISH FTS-2
# ['JEA', 'THE ENERGY AUTHORITY, INC.'] ANR ST LANDRY PARISH FTS-1
# ['JEA', 'THE ENERGY AUTHORITY, INC.'] ANR ST LANDRY PARISH FTS-1
# ['ORANGE COGENERATION LIMITED PARTNERSHIP', 'RAINBOW ENERGY MARKETING CORPORATION'] ANR ST LANDRY PARISH FTS-2
# ['DUKE ENERGY FLORIDA, LLC'] ANR ST LANDRY PARISH FTS-1
# ['GAINESVILLE REGIONAL UTILITIES', 'THE ENERGY AUTHORITY, INC.'] ANR ST LANDRY PARISH FTS-1
# ['DUKE ENERGY FLORIDA, LLC'] ANR ST LANDRY PARISH FTS-2
# ['TAMPA ELECTRIC COMPANY'] ANR ST LANDRY PARISH FTS-2
# ['TAMPA ELECTRIC COMPANY'] ANR ST LANDRY PARISH FTS-1
# ['TAMPA ELECTRIC COMPANY'] ANR ST LANDRY PARISH FTS-1
# ['ORLANDO UTILITIES COMMISSION'] ANR ST LANDRY PARISH FTS-2
# ['DUKE ENERGY FLORIDA, LLC'] ANR ST LANDRY PARISH FTS-1
# ['OKALOOSA GAS DISTRICT', 'GAS SOUTH, LLC'] ANR ST LANDRY PARISH
# ['OKALOOSA GAS DISTRICT', 'GAS SOUTH, LLC'] ANR ST LANDRY PARISH
# ['ORLANDO COGEN LIMITED, L.P.', 'BP ENERGY COMPANY'] ANR ST LANDRY PARISH FTS-2
# ['PEOPLES GAS SYSTEM, INC.', 'PEOPLES GAS SYSTEM, A DIVISION OF TAMPA', 'PERRY, CITY OF', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH FTS-2
# ['ORLANDO UTILITIES COMMISSION'] ANR ST LANDRY PARISH FTS-2
# ['TOWN OF JAY', 'FLORIDA GAS UTILITY'] ANR ST LANDRY PARISH
# ['FLORIDA PUBLIC UTILITIES COMPANY'] ANR ST LANDRY PARISH FTS-2
# ['SHELL ENERGY NORTH AMERICA (US), L.P.'] EUNICE - ANR
# ['ORLANDO UTILITIES COMMISSION'] ANR ST LANDRY PARISH FTS-1
# ['OKALOOSA GAS DISTRICT'] ANR ST LANDRY PARISH FTS-1
# Enter e to end or press enter to continuee
