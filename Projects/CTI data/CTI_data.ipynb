# %%
import json
import os

def extract_threat_actors_from_folder(folder_path):
    threat_actors = []

    # Iterate over each file in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Check if the file is a JSON file
        if file_name.endswith('.json'):
            with open(file_path, 'r') as json_file:
                try:
                    json_data = json.load(json_file)
                    threat_actor = extract_threat_actor(json_data)
                    threat_actors.append(threat_actor)
                except json.JSONDecodeError:
                    print(f"Error parsing JSON file: {file_path}")

    return threat_actors

def extract_threat_actor(json_data):
    threat_actor = {}

    if 'objects' in json_data and isinstance(json_data['objects'], list):
        for obj in json_data['objects']:
            if obj.get('type') == 'intrusion-set':
                threat_actor['id'] = obj.get('id')
                threat_actor['name'] = obj.get('name')
                #threat_actor['aliases'] = obj.get('aliases', [])
                #threat_actor['description'] = obj.get('description')
                # Add more attributes as needed

    return threat_actor


# Provide the path to the folder containing the JSON files
folder_path = 'F:\Projects\CTI\enterprise-attack\intrusion-set'

# Extract threat actors from the folder
threat_actors = extract_threat_actors_from_folder(folder_path)

# Print the extracted threat actors
for threat_actor in threat_actors:
    print(threat_actor)
print(len(threat_actors))
# Out:
# {'id': 'intrusion-set--00f67a77-86a4-4adf-be26-1a54fc713340', 'name': 'APT38'}
# {'id': 'intrusion-set--190242d7-73fc-4738-af68-20162f7a5aae', 'name': 'ALLANITE'}
# {'id': 'intrusion-set--1c63d4ec-0a75-4daa-b1df-0d11af3d3cc1', 'name': 'Dragonfly'}
# {'id': 'intrusion-set--2a7914cf-dff3-428d-ab0f-1014d1c28aeb', 'name': 'FIN6'}
# {'id': 'intrusion-set--3753cc21-2dae-4dfb-8481-d004e74502cc', 'name': 'FIN7'}
# {'id': 'intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc35192', 'name': 'Sandworm Team'}
# {'id': 'intrusion-set--4ca1929c-7d64-4aab-b849-badbfc0c760d', 'name': 'OilRig'}
# {'id': 'intrusion-set--68ba94ab-78b8-43e7-83e2-aed3466882c6', 'name': 'APT34'}
# {'id': 'intrusion-set--76d59913-1d24-4992-a8ac-05a3eb093f71', 'name': 'Dragonfly 2.0'}
# {'id': 'intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fcab05a4', 'name': 'TEMP.Veles'}
# {'id': 'intrusion-set--c77c5576-ca19-42ed-a36f-4b4486a84133', 'name': 'GOLD SOUTHFIELD'}
# {'id': 'intrusion-set--c93fccb1-e8e8-42cf-ae33-2ad1d183913a', 'name': 'Lazarus Group'}
# {'id': 'intrusion-set--dd2d9ca6-505b-4860-a604-233685b802c7', 'name': 'Wizard Spider'}
# {'id': 'intrusion-set--f29b7c5e-2439-42ad-a86f-9f8984fafae3', 'name': 'HEXANE'}
# {'id': 'intrusion-set--fbd29c89-18ba-4c2d-b792-51c0adee049f', 'name': 'APT33'}
# 15

# %%
def extract_ttps_from_folder(folder_path):
    ttps = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.endswith('.json'):
            with open(file_path, 'r') as file:
                json_data = json.load(file)
                ttps.extend(extract_ttps(json_data))

    return ttps

def extract_ttps(json_data):
    ttps = []

    if 'objects' in json_data and isinstance(json_data['objects'], list):
        for obj in json_data['objects']:
            if obj.get('type') == 'attack-pattern':
                ttp = {
                    'id': obj.get('id'),
                    'name': obj.get('name'),
                    'external_id': obj['external_references'][0].get('external_id')
                }
                ttps.append(ttp)

    return ttps


# Example usage
folder_path = "F:\\Projects\\CTI\\enterprise-attack\\attack-pattern"
ttps = extract_ttps_from_folder(folder_path)

# Print the extracted TTPs
for ttp in ttps:
    print('ID:', ttp['id'])
    print('Name:', ttp['name'])
    print('External_id:', ttp['external_id'])
    print('---')
    
print(len(ttps))
# Out:
# ID: attack-pattern--008b8f56-6107-48be-aa9f-746f927dbb61
# Name: Block Command Message
# External_id: T0803
# ---
# ID: attack-pattern--063b5b92-5361-481a-9c3f-95492ed9a2d8
# Name: Service Stop
# External_id: T0881
# ---
# ID: attack-pattern--097924ce-a9a9-4039-8591-e0deedfb8722
# Name: Modify Parameter
# External_id: T0836
# ---
# ID: attack-pattern--09a61657-46e1-439e-b3ed-3e4556a78243
# Name: Modify Controller Tasking
# External_id: T0821
# ---
# ID: attack-pattern--0fe075d5-beac-4d02-b93e-0f874997db72
# Name: Wireless Sniffing
# External_id: T0887
# ---
# ID: attack-pattern--138979ba-0430-4de6-a128-2fc0b056ba36
# Name: Loss of View
# External_id: T0829
# ---
# ID: attack-pattern--19a71d1e-6334-4233-8260-b749cae37953
# Name: Activate Firmware Update Mode
# External_id: T0800
# ---
# ID: attack-pattern--1af9e3fd-2bcc-414d-adbd-fe3b95c02ca1
# Name: Manipulation of Control
# External_id: T0831
# ---
# ID: attack-pattern--1b22b676-9347-4c55-9a35-ef0dc653db5b
# Name: Denial of Service
# External_id: T0814
# ---
# ID: attack-pattern--1c478716-71d9-46a4-9a53-fa5d576adb60
# Name: Block Serial COM
# External_id: T0805
# ---
# ID: attack-pattern--23270e54-1d68-4c3b-b763-b25607bcef80
# Name: Role Identification
# External_id: T0850
# ---
# ID: attack-pattern--24a9253e-8948-4c98-b751-8e2aee53127c
# Name: Command-Line Interface
# External_id: T0807
# ---
# ID: attack-pattern--25852363-5968-4673-b81d-341d5ed90bd1
# Name: Point & Tag Identification
# External_id: T0861
# ---
# ID: attack-pattern--25dfc8ad-bd73-4dfd-84a9-3c3d383f76e9
# Name: Device Restart/Shutdown
# External_id: T0816
# ---
# ID: attack-pattern--2736b752-4ec5-4421-a230-8977dea7649c
# Name: User Execution
# External_id: T0863
# ---
# ID: attack-pattern--2877063e-1851-48d2-bcc6-bc1d2733157e
# Name: Wireless Compromise
# External_id: T0860
# ---
# ID: attack-pattern--2883c520-7957-46ca-89bd-dab1ad53b601
# Name: Change Operating Mode
# External_id: T0858
# ---
# ID: attack-pattern--2900bbd8-308a-4274-b074-5b8bde8347bc
# Name: Alarm Suppression
# External_id: T0878
# ---
# ID: attack-pattern--2aa406ed-81c3-4c1d-ba83-cfbee5a2847a
# Name: Detect Operating Mode
# External_id: T0868
# ---
# ID: attack-pattern--2bb4d762-bf4a-4bc3-9318-15cc6a354163
# Name: Loss of Protection
# External_id: T0837
# ---
# ID: attack-pattern--2d0d40ad-22fa-4cc8-b264-072557e1364b
# Name: Monitor Process State
# External_id: T0801
# ---
# ID: attack-pattern--2dc2b567-8821-49f9-9045-8740f3d0b958
# Name: Scripting
# External_id: T0853
# ---
# ID: attack-pattern--2fedbe69-581f-447d-8a78-32ee7db939a9
# Name: Remote System Information Discovery
# External_id: T0888
# ---
# ID: attack-pattern--3067b85e-271e-4bc5-81ad-ab1a81d411e3
# Name: Program Upload
# External_id: T0845
# ---
# ID: attack-pattern--32632a95-6856-47b9-9ab7-fea5cd7dce00
# Name: Exploit Public-Facing Application
# External_id: T0819
# ---
# ID: attack-pattern--3405891b-16aa-4bd7-bd7c-733501f9b20f
# Name: Data from Information Repositories
# External_id: T0811
# ---
# ID: attack-pattern--35392fb4-a31d-4c6a-b9f2-1c65b7f5e6b9
# Name: Transient Cyber Asset
# External_id: T0864
# ---
# ID: attack-pattern--36e9f5bc-ac13-4da4-a2f4-01f4877d9004
# Name: Manipulate I/O Image
# External_id: T0835
# ---
# ID: attack-pattern--38213338-1aab-479d-949b-c81b66ccca5c
# Name: Network Sniffing
# External_id: T0842
# ---
# ID: attack-pattern--3b6b9246-43f8-4c69-ad7a-2b11cfe0a0d9
# Name: Rootkit
# External_id: T0851
# ---
# ID: attack-pattern--3de230d4-3e42-4041-b089-17e1128feded
# Name: Automated Collection
# External_id: T0802
# ---
# ID: attack-pattern--3f1f4ccb-9be2-4ff8-8f69-dd972221169b
# Name: Block Reporting Message
# External_id: T0804
# ---
# ID: attack-pattern--40b300ba-f553-48bf-862e-9471b220d455
# Name: Unauthorized Command Message
# External_id: T0855
# ---
# ID: attack-pattern--493832d9-cea6-4b63-abe7-9a65a6473675
# Name: Data Destruction
# External_id: T0809
# ---
# ID: attack-pattern--4c2e1408-9d68-4187-8e6b-a77bc52700ec
# Name: Manipulation of View
# External_id: T0832
# ---
# ID: attack-pattern--50d3222f-7550-4a3c-94e1-78cb6c81d064
# Name: Data Historian Compromise
# External_id: T0810
# ---
# ID: attack-pattern--539d0484-fe95-485a-b654-86991c0d0d00
# Name: Network Service Scanning
# External_id: T0841
# ---
# ID: attack-pattern--53a26eee-1080-4d17-9762-2027d5a1b805
# Name: Indicator Removal on Host
# External_id: T0872
# ---
# ID: attack-pattern--53a48c74-0025-45f4-b04a-baa853df8204
# Name: I/O Image
# External_id: T0877
# ---
# ID: attack-pattern--56ddc820-6cfb-407f-850b-52c035d123ac
# Name: Denial of View
# External_id: T0815
# ---
# ID: attack-pattern--5a2610f6-9fff-41e1-bc27-575ca20383d4
# Name: Execution through API
# External_id: T0871
# ---
# ID: attack-pattern--5e0f75da-e108-4688-a6de-a4f07cc2cbe3
# Name: Supply Chain Compromise
# External_id: T0862
# ---
# ID: attack-pattern--5f3da2f3-91c8-4d8b-a02f-bf43a11def55
# Name: Serial Connection Enumeration
# External_id: T0854
# ---
# ID: attack-pattern--5fa00fdd-4a55-4191-94a0-564181d7fec2
# Name: Loss of Safety
# External_id: T0880
# ---
# ID: attack-pattern--63b6942d-8359-4506-bfb3-cf87aa8120ee
# Name: Loss of Productivity and Revenue
# External_id: T0828
# ---
# ID: attack-pattern--648f995e-9c3a-41e4-aeee-98bb41037426
# Name: Spearphishing Attachment
# External_id: T0865
# ---
# ID: attack-pattern--7374ab87-0782-41f8-b415-678c0950bb2a
# Name: Location Identification
# External_id: T0825
# ---
# ID: attack-pattern--7830cfcf-b268-4ac0-a69e-73c6affbae9a
# Name: Drive-by Compromise
# External_id: T0817
# ---
# ID: attack-pattern--83ebd22f-b401-4d59-8219-2294172cf916
# Name: Damage to Property
# External_id: T0879
# ---
# ID: attack-pattern--8535b71e-3c12-4258-a4ab-40257a1becc4
# Name: Spoof Reporting Message
# External_id: T0856
# ---
# ID: attack-pattern--85a45294-08f1-4539-bf00-7da08aa7b0ee
# Name: Exploitation of Remote Services
# External_id: T0866
# ---
# ID: attack-pattern--8bb4538f-f16f-49f0-a431-70b5444c7349
# Name: Default Credentials
# External_id: T0812
# ---
# ID: attack-pattern--8d2f3bab-507c-4424-b58b-edc977bd215c
# Name: External Remote Services
# External_id: T0822
# ---
# ID: attack-pattern--8e7089d3-fba2-44f8-94a8-9a79c53920c4
# Name: Brute Force I/O
# External_id: T0806
# ---
# ID: attack-pattern--94f042ae-3033-4a8d-9ec3-26396533a541
# Name: Detect Program State
# External_id: T0870
# ---
# ID: attack-pattern--9a505987-ab05-4f46-a9a6-6441442eec3b
# Name: Adversary-in-the-Middle
# External_id: T0830
# ---
# ID: attack-pattern--9f947a1c-3860-48a8-8af0-a2dfa3efde03
# Name: Exploitation for Evasion
# External_id: T0820
# ---
# ID: attack-pattern--a81696ef-c106-482c-8f80-59c30f2569fb
# Name: Loss of Control
# External_id: T0827
# ---
# ID: attack-pattern--a8cfd474-9358-464f-a169-9c6f099a8e8a
# Name: Change Program State
# External_id: T0875
# ---
# ID: attack-pattern--ab390887-afc0-4715-826d-b1b167d522ae
# Name: Hooking
# External_id: T0874
# ---
# ID: attack-pattern--abb0a255-eb9c-48d0-8f5c-874bb84c0e45
# Name: Control Device Identification
# External_id: T0808
# ---
# ID: attack-pattern--ae62fe1a-ea1a-479b-8dc0-65d250bd8bc7
# Name: Program Organization Units
# External_id: T0844
# ---
# ID: attack-pattern--b0628bfc-5376-4a38-9182-f324501cb4cf
# Name: Graphical User Interface
# External_id: T0823
# ---
# ID: attack-pattern--b14395bd-5419-4ef4-9bd8-696936f509bb
# Name: Rogue Master
# External_id: T0848
# ---
# ID: attack-pattern--b52870cc-83f3-473c-b895-72d91751030b
# Name: Native API
# External_id: T0834
# ---
# ID: attack-pattern--b5b9bacb-97f2-4249-b804-47fd44de1f95
# Name: Loss of Availability
# External_id: T0826
# ---
# ID: attack-pattern--b7e13ee8-182c-4f19-92a4-a88d7d855d54
# Name: Theft of Operational Information
# External_id: T0882
# ---
# ID: attack-pattern--b9160e77-ea9e-4ba9-b1c8-53a3c466b13d
# Name: System Firmware
# External_id: T0857
# ---
# ID: attack-pattern--ba203963-3182-41ac-af14-7e7ebc83cd61
# Name: Masquerading
# External_id: T0849
# ---
# ID: attack-pattern--be69c571-d746-4b1f-bdd0-c0c9817e9068
# Name: Program Download
# External_id: T0843
# ---
# ID: attack-pattern--c267bbee-bb59-47fe-85e0-3ed210337c21
# Name: Replication Through Removable Media
# External_id: T0847
# ---
# ID: attack-pattern--c5e3cdbc-0387-4be9-8f83-ff5c0865f377
# Name: Screen Capture
# External_id: T0852
# ---
# ID: attack-pattern--c9a8d958-fcdb-40d2-af4c-461c8031651a
# Name: Hardcoded Credentials
# External_id: T0891
# ---
# ID: attack-pattern--cd2c76a4-5e23-4ca5-9c40-d5e0604f7101
# Name: Valid Accounts
# External_id: T0859
# ---
# ID: attack-pattern--cfe68e93-ce94-4c0f-a57d-3aa72cedd618
# Name: Exploitation for Privilege Escalation
# External_id: T0890
# ---
# ID: attack-pattern--d5a69cfb-fc2a-46cb-99eb-74b236db5061
# Name: Remote System Discovery
# External_id: T0846
# ---
# ID: attack-pattern--d614a9cf-18eb-4800-81e4-ab8ddf0baa73
# Name: Engineering Workstation Compromise
# External_id: T0818
# ---
# ID: attack-pattern--d67adac8-e3b9-44f9-9e6d-6c2a7d69dbe4
# Name: Connection Proxy
# External_id: T0884
# ---
# ID: attack-pattern--e076cca8-2f08-45c9-aff7-ea5ac798b387
# Name: Standard Application Layer Protocol
# External_id: T0869
# ---
# ID: attack-pattern--e0d74479-86d2-465d-bf36-903ebecef43e
# Name: Modify Control Logic
# External_id: T0833
# ---
# ID: attack-pattern--e1f9cdd2-9511-4fca-90d7-f3e92cfdd0bf
# Name: Remote Services
# External_id: T0886
# ---
# ID: attack-pattern--e2994b6a-122b-4043-b654-7411c5198ec0
# Name: I/O Module Discovery
# External_id: T0824
# ---
# ID: attack-pattern--e33c7ecc-5a38-497f-beb2-a9a2049a4c20
# Name: Denial of Control
# External_id: T0813
# ---
# ID: attack-pattern--e5de767e-f513-41cd-aa15-33f6ce5fbf92
# Name: Modify Alarm Settings
# External_id: T0838
# ---
# ID: attack-pattern--e6c31185-8040-4267-83d3-b217b8a92f07
# Name: Commonly Used Port
# External_id: T0885
# ---
# ID: attack-pattern--e72425f8-9ae6-41d3-bfdb-e1b865e60722
# Name: Project File Infection
# External_id: T0873
# ---
# ID: attack-pattern--ea0c980c-5cf0-43a7-a049-59c4c207566e
# Name: Network Connection Enumeration
# External_id: T0840
# ---
# ID: attack-pattern--ead7bd34-186e-4c79-9a4d-b65bcce6ed9d
# Name: Lateral Tool Transfer
# External_id: T0867
# ---
# ID: attack-pattern--efbf7888-f61b-4572-9c80-7e2965c60707
# Name: Module Firmware
# External_id: T0839
# ---
# ID: attack-pattern--f8df6b57-14bc-425f-9a91-6f59f6799307
# Name: Internet Accessible Device
# External_id: T0883
# ---
# ID: attack-pattern--fa3aa267-da22-4bdd-961f-03223322a8d5
# Name: Data from Local System
# External_id: T0893
# ---
# ID: attack-pattern--fab8fc7d-f27f-4fbb-9de6-44740aade05f
# Name: Change Credential
# External_id: T0892
# ---
# ID: attack-pattern--fc5fda7e-6b2c-4457-b036-759896a2efa2
# Name: Modify Program
# External_id: T0889
# ---
# 93

# %%
def extract_malware_from_folder(folder_path):
    malware_list = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                try:
                    json_data = json.load(file)
                    malware = extract_malware(json_data)
                    if malware:
                        malware_list.append(malware)
                except json.JSONDecodeError:
                    print(f"Error decoding JSON file: {file_path}")
                except KeyError:
                    print(f"Missing key in JSON file: {file_path}")

    return malware_list


def extract_malware(json_data):
    malware = None

    if 'objects' in json_data and isinstance(json_data['objects'], list):
        for obj in json_data['objects']:
            if obj.get('type') == 'malware':
                malware = {
                    'id': obj.get('id'),
                    'name': obj.get('name')
                }
                break

    return malware


# Example usage
folder_path = "F:\Projects\CTI\enterprise-attack\malware"
malware_objects = extract_malware_from_folder(folder_path)

for malware in malware_objects:
    print(f"ID: {malware['id']}, Name: {malware['name']}")
    
print(len(malware_objects))
# Out:
# ID: malware--00e7d565-9883-4ee5-b642-8fd17fd6a3f5, Name: EKANS
# ID: malware--083bb47b-02c8-4423-81a2-f9ef58572974, Name: Backdoor.Oldrea
# ID: malware--088f1d6e-0783-47c6-9923-9c79b2af43d4, Name: Stuxnet
# ID: malware--1d8dccb3-e779-4702-aeb1-6627a22cc585, Name: Industroyer
# ID: malware--242622ca-3903-43d5-8aa0-3bbdaa3020ec, Name: Bad Rabbit
# ID: malware--2eaa5319-5e1e-4dd7-bbc4-566fced3964a, Name: Bad Rabbit
# ID: malware--496bff4d-0700-4b28-b06f-f30a63002be7, Name: Stuxnet
# ID: malware--49c04994-1035-4b58-89b7-cf8956e3b423, Name: Conficker
# ID: malware--4dcff507-5af8-47ce-964a-8d9569e9ccfe, Name: PLC-Blaster
# ID: malware--54cc1d4f-5c53-4f0e-9ef5-11b4998e82e4, Name: BlackEnergy
# ID: malware--5719af9d-6b16-46f9-9b28-fb019541ddbb, Name: NotPetya
# ID: malware--58eddbaf-7416-419a-ad7b-e65b9d4c3b55, Name: Conficker
# ID: malware--5af7a825-2d9f-400d-931a-e00eb9e27f48, Name: LockerGoga
# ID: malware--6108f800-10b8-4090-944e-be579f01263d, Name: VPNFilter
# ID: malware--68dca94f-c11d-421e-9287-7c501108e18c, Name: Duqu
# ID: malware--6a0d0ea9-b2c4-43fe-a552-ac41a3009dc5, Name: Industroyer2
# ID: malware--736a3b71-eccc-48b7-b5ed-adb2b74ca830, Name: Killdisk
# ID: malware--75ecdbf1-c2bb-4afc-a3f9-c8da4de8c661, Name: WannaCry
# ID: malware--80099a91-4c86-4bea-9ccb-dac55d61960e, Name: Triton
# ID: malware--89ab0ca5-f7e0-4d16-bf2a-17d68117fa4b, Name: BlackEnergy 3
# ID: malware--9e3c9495-5fbd-4676-b3ac-ddecceb57b8f, Name: EKANS
# ID: malware--a020a61c-423f-4195-8c46-ba1d21abba37, Name: Ryuk
# ID: malware--a4a98eab-b691-45d9-8c48-869ef8fefd57, Name: ACAD/Medre.A
# ID: malware--ac61f1f9-7bb1-465e-9b8a-c2ce8e88baf5, Name: REvil
# ID: malware--d3aa1058-b1b3-4c29-a3ba-9a9b90ccd93b, Name: INCONTROLLER
# ID: malware--e221eb77-1502-4129-af1d-fe1ad55e7ec6, Name: KillDisk
# ID: malware--e401d4fe-f0c9-44f0-98e6-f93487678808, Name: Industroyer
# ID: malware--ff6840c9-4c87-4d07-bbb6-9f50aa33d498, Name: Flame
# 28

# %%
def extract_relationships_from_folder(folder_path):
    relationships = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                try:
                    json_data = json.load(file)
                    relationship = extract_relationship(json_data)
                    if relationship:
                        relationships.append(relationship)
                except json.JSONDecodeError:
                    print(f"Error decoding JSON file: {file_path}")
                except KeyError:
                    print(f"Missing key in JSON file: {file_path}")

    return relationships


def extract_relationship(json_data):
    relationship = None

    if 'objects' in json_data and isinstance(json_data['objects'], list):
        for obj in json_data['objects']:
            if obj.get('type') == 'relationship':
                relationship = {
                    'id': obj.get('id'),
                    'type': obj.get('relationship_type'),
                    'source_ref': obj.get('source_ref'),
                    'target_ref': obj.get('target_ref')
                }
                break

    return relationship

# Example usage
folder_path = "F:\\Projects\\CTI\\enterprise-attack\\relationship"
relationships = extract_relationships_from_folder(folder_path)

for relationship in relationships:
    print('ID:', relationship['id'])
    print('Type:', relationship['type'])
    print('Source Ref:', relationship['source_ref'])
    print('Target Ref:', relationship['target_ref'])
    print('---')

print(len(relationships))
# Out:
# ID: relationship--00b98fa6-4913-40a4-8920-befed8621c41
# Type: detects
# Source Ref: x-mitre-data-component--9c2fa0ae-7abc-485a-97f6-699e3b6cf9fa
# Target Ref: attack-pattern--e5de767e-f513-41cd-aa15-33f6ce5fbf92
# ---
# ID: relationship--00e6c22b-9275-4039-b6d4-2ac0680325d6
# Type: mitigates
# Source Ref: course-of-action--aadac250-bcdc-44e3-a4ae-f52bd0a7a16a
# Target Ref: attack-pattern--25dfc8ad-bd73-4dfd-84a9-3c3d383f76e9
# ---
# ID: relationship--01b4a92f-da42-4dfa-8d59-53709b65940e
# Type: mitigates
# Source Ref: course-of-action--e57ebc6d-785f-40c8-adb1-b5b5e09b3b48
# Target Ref: attack-pattern--063b5b92-5361-481a-9c3f-95492ed9a2d8
# ---
# ID: relationship--0278ddbc-67d5-444d-8082-bf9974dee920
# Type: detects
# Source Ref: x-mitre-data-component--a953ca55-921a-44f7-9b8d-3d40141aa17e
# Target Ref: attack-pattern--cd2c76a4-5e23-4ca5-9c40-d5e0604f7101
# ---
# ID: relationship--028a3bcc-f299-4061-a0f2-8da85e0a3c81
# Type: mitigates
# Source Ref: course-of-action--72e46e53-e12d-4106-9c70-33241b6ed549
# Target Ref: attack-pattern--be69c571-d746-4b1f-bdd0-c0c9817e9068
# ---
# ID: relationship--03a9cdc7-3cc5-43e3-9a9c-97d1c4310e35
# Type: mitigates
# Source Ref: course-of-action--66cfe23e-34b6-4583-b178-ed6a412db2b0
# Target Ref: attack-pattern--e5de767e-f513-41cd-aa15-33f6ce5fbf92
# ---
# ID: relationship--03ad6a9a-4443-4e33-a7a5-933e22f2e022
# Type: detects
# Source Ref: x-mitre-data-component--f5468e67-51c7-4756-9b4f-65707708e7fa
# Target Ref: attack-pattern--ead7bd34-186e-4c79-9a4d-b65bcce6ed9d
# ---
# ID: relationship--03d44496-7a15-4e23-820f-b6f1079dbbd3
# Type: mitigates
# Source Ref: course-of-action--97f33c84-8508-45b9-8a1d-cac921828c9e
# Target Ref: attack-pattern--5e0f75da-e108-4688-a6de-a4f07cc2cbe3
# ---
# ID: relationship--03e80e3c-28b9-4e7f-8b17-7c86d1483b91
# Type: mitigates
# Source Ref: course-of-action--9f99fcfd-772e-4e63-9d39-e45612e546dc
# Target Ref: attack-pattern--fa3aa267-da22-4bdd-961f-03223322a8d5
# ---
# ID: relationship--042243fd-bfe0-4961-96de-a36232d3ff74
# Type: uses
# Source Ref: intrusion-set--1c63d4ec-0a75-4daa-b1df-0d11af3d3cc1
# Target Ref: attack-pattern--7830cfcf-b268-4ac0-a69e-73c6affbae9a
# ---
# ID: relationship--04882fef-2a6b-40d0-a101-da9c76a3572e
# Type: mitigates
# Source Ref: course-of-action--2ab9fc6d-3cf6-4d7b-85f1-3ad6949233b3
# Target Ref: attack-pattern--ab390887-afc0-4715-826d-b1b167d522ae
# ---
# ID: relationship--0491ef92-2941-4841-9fe6-2e1809788b52
# Type: mitigates
# Source Ref: course-of-action--bcf91ebc-f316-4e19-b2f6-444e9940c697
# Target Ref: attack-pattern--5e0f75da-e108-4688-a6de-a4f07cc2cbe3
# ---
# ID: relationship--04bf72de-75ba-4d95-ad24-f93ad835180c
# Type: uses
# Source Ref: malware--e221eb77-1502-4129-af1d-fe1ad55e7ec6
# Target Ref: attack-pattern--138979ba-0430-4de6-a128-2fc0b056ba36
# ---
# ID: relationship--04fa6b94-d633-40ff-9ab2-88f58c07c3e1
# Type: mitigates
# Source Ref: course-of-action--bcf91ebc-f316-4e19-b2f6-444e9940c697
# Target Ref: attack-pattern--b9160e77-ea9e-4ba9-b1c8-53a3c466b13d
# ---
# ID: relationship
# Type: detects
# Source Ref: x-mitre-data-component--3772e279-27d6-477a-9fe3-c6beb363594c
# Target Ref: attack-pattern--b9160e77-ea9e-4ba9-b1c8-53a3c466b13d
# ---
# ID: relationship--fc3d0a84-e7c7-415c-ae47-42bc513e9bf9
# Type: detects
# Source Ref: x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a
# Target Ref: attack-pattern--ead7bd34-186e-4c79-9a4d-b65bcce6ed9d
# ---
# ID: relationship--fc4803cb-d6bf-4674-bf40-d4b0997824ba
# Type: uses
# Source Ref: intrusion-set--190242d7-73fc-4738-af68-20162f7a5aae
# Target Ref: attack-pattern--7830cfcf-b268-4ac0-a69e-73c6affbae9a
# ---
# ID: relationship--fc6cc5f2-ef5b-4a28-a0b2-a277ee98191d
# Type: detects
# Source Ref: x-mitre-data-component--3772e279-27d6-477a-9fe3-c6beb363594c
# Target Ref: attack-pattern--2736b752-4ec5-4421-a230-8977dea7649c
# ---
# ID: relationship--fcb7733f-553d-43de-a8c6-c85a5cd65041
# Type: mitigates
# Source Ref: course-of-action--1e7ccfc0-94c8-496e-8d27-032120892291
# Target Ref: attack-pattern--32632a95-6856-47b9-9ab7-fea5cd7dce00
# ---
# ID: relationship--fcd3fdbf-4909-48ab-85c4-ce4b34172eb0
# Type: mitigates
# Source Ref: course-of-action--143b4398-3222-480a-b6a4-e131bc2d3144
# Target Ref: attack-pattern--7830cfcf-b268-4ac0-a69e-73c6affbae9a
# ---
# ID: relationship--fd0340cc-6105-4abd-89d0-60b0d9c00b55
# Type: detects
# Source Ref: x-mitre-data-component--8ed4e6d0-56d7-4e6b-8fa6-41f41631f30d
# Target Ref: attack-pattern--53a48c74-0025-45f4-b04a-baa853df8204
# ---
# ID: relationship--fd856176-396c-4121-9754-35e49bfa5758
# Type: detects
# Source Ref: x-mitre-data-component--181a9f8c-c780-4f1f-91a8-edb770e904ba
# Target Ref: attack-pattern--7830cfcf-b268-4ac0-a69e-73c6affbae9a
# ---
# ID: relationship--fe22637e-7187-4990-b24a-5dc851eec736
# Type: detects
# Source Ref: x-mitre-data-component--931b3fc6-ad68-42a8-9018-e98515eedc95
# Target Ref: attack-pattern--3f1f4ccb-9be2-4ff8-8f69-dd972221169b
# ---
# ID: relationship--ff3f0668-98df-44c1-88c2-711f05720eb8
# Type: mitigates
# Source Ref: course-of-action--e0d38502-decb-481d-ad8b-b8f0a0c330bd
# Target Ref: attack-pattern--19a71d1e-6334-4233-8260-b749cae37953
# ---
# ID: relationship--ffc5bbce-8d9c-4276-9dc6-efed5c01af8b
# Type: uses
# Source Ref: malware--2eaa5319-5e1e-4dd7-bbc4-566fced3964a
# Target Ref: attack-pattern--ead7bd34-186e-4c79-9a4d-b65bcce6ed9d
# ---
# 781

# %%
def get_entity_name_enterprise():
    entity_data = []
    
    for relationship in relationships:
        if relationship['source_ref'].startswith('intrusion-set'):
            threat_actor_id = relationship['source_ref']
            
            for threat_actor in threat_actors:
                if threat_actor['id'] == threat_actor_id:
                    threat_actor_name = threat_actor['name']
                    break
                    
            if relationship['target_ref'].startswith('attack-pattern'):
                for ttp in ttps:
                    if ttp['id'] == relationship['target_ref']:
                        ttp_id = ttp['external_id']
                        if threat_actor_name.startswith('APT'):
                            entity_data.append({
                                'name': threat_actor_name,
                                'type': relationship['type'],
                                'ttp': ttp_id
                            })
                        break
           
            elif relationship['target_ref'].startswith('malware'):
                for malware in malware_objects:
                    if malware['id'] == relationship['target_ref']:
                        malware_name = malware['name']
                        if threat_actor_name.startswith('APT'):
                            entity_data.append({
                                'name': threat_actor_name,
                                'type': relationship['type'],
                                'malware': malware_name
                            })
                        break
                        
    return entity_data

# %% [markdown]
# ### Reuse the above codes to generate dictionaries for mobile attacks and ics attaks

# %%
enterprise_dict = get_entity_name_enterprise()

def append_dictionaries(enterprise_dict, mobile_dict, ics_dict):
    appended_dict = enterprise_dict.copy()
    
    for i in s:
        appended_dict.append(i)
    for i in t:
        appended_dict.append(i)
    return appended_dict
qu = append_dictionaries(enterprise_dict,s,t)

print(len(qu))
qu
# Out:
# 679
# [{'name': 'APT28', 'type': 'uses', 'ttp': 'T1003.003'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'PinchDuke'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1046'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1486'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'WellMail'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1078'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'CozyCar'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1589.001'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1033'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1090.002'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1550.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1140'},
#  {'name': 'APT30', 'type': 'uses', 'malware': 'SHIPSHAPE'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1564.001'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1120'},
#  {'name': 'APT12', 'type': 'uses', 'ttp': 'T1204.002'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1053.005'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1621'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1112'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1583.001'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1059.006'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1036'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1056.001'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1005'},
#  {'name': 'APT1', 'type': 'uses', 'malware': 'Seasalt'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1059.001'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1115'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1003'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1070.006'},
#  {'name': 'APT38', 'type': 'uses', 'malware': 'ECCENTRICBANDWAGON'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1090.002'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1195.002'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'TrailBlazer'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1049'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1059.001'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1104'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1110.002'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'OnionDuke'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1566.001'},
#  {'name': 'APT41', 'type': 'uses', 'malware': 'ASPXSpy'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1070.004'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1552.001'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1059.001'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1048.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1553.006'},
#  {'name': 'APT3', 'type': 'uses', 'malware': 'OSInfo'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1003.005'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1059.007'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'BLUELIGHT'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1047'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1546.010'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1105'},
#  {'name': 'APT1', 'type': 'uses', 'malware': 'BISCUIT'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1056.001'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1059.001'},
#  {'name': 'APT18', 'type': 'uses', 'ttp': 'T1078'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1027'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1203'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1586.002'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1114.002'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1014'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1564.003'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1518.001'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1072'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'CORALDECK'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1071.001'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1570'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1564.004'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1560.001'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1505.003'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1027.003'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1543.003'},
#  {'name': 'APT-C-36', 'type': 'uses', 'ttp': 'T1204.002'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'KARAE'},
#  {'name': 'APT39', 'type': 'uses', 'malware': 'MechaFlounder'},
#  {'name': 'APT41', 'type': 'uses', 'malware': 'PlugX'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1550.002'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1588.002'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1037.001'},
#  {'name': 'APT18', 'type': 'uses', 'ttp': 'T1027'},
#  {'name': 'APT28', 'type': 'uses', 'malware': 'CHOPSTICK'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1588.002'},
#  {'name': 'APT33', 'type': 'uses', 'malware': 'AutoIt backdoor'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1547.009'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'SLOWDRIFT'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'FatDuke'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1090.004'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1564.003'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1036.005'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1003.001'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1543.003'},
#  {'name': 'APT39', 'type': 'uses', 'malware': 'Remexi'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1090.003'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1567'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1071.002'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1189'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1056.001'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1068'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'POSHSPY'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1564.003'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1083'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1552.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1135'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1083'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'EnvyScout'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1553.002'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1016'},
#  {'name': 'APT1', 'type': 'uses', 'malware': 'GLOOXMAIL'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1190'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1102.002'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1033'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1546.003'},
#  {'name': 'APT3', 'type': 'uses', 'malware': 'PlugX'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT32', 'type': 'uses', 'malware': 'Kerrdown'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1588.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1569.002'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'SoreFang'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1055'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1216.001'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1098'},
#  {'name': 'APT41', 'type': 'uses', 'malware': 'gh0st RAT'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1057'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1005'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1027'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1555.003'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1136.003'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1021.002'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1566.001'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1059.003'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'GeminiDuke'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1550.002'},
#  {'name': 'APT18', 'type': 'uses', 'ttp': 'T1133'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1555.003'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1218.011'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1098.005'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1587.003'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1135'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1105'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1552.006'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1651'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1588.002'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1082'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1027'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1033'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1571'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1583.001'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1136.001'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1566.001'},
#  {'name': 'APT38', 'type': 'uses', 'malware': 'HOPLIGHT'},
#  {'name': 'APT17', 'type': 'uses', 'ttp': 'T1583.006'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1059.003'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T
},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1104'},
#  {'name': 'APT3', 'type': 'uses', 'malware': 'RemoteCMD'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1574.002'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1047'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1204.002'},
#  {'name': 'APT41', 'type': 'uses', 'malware': 'Winnti for Linux'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1056.001'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1547.001'},
#  {'name': 'APT38', 'type': 'uses', 'ttp': 'T1057'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1053.005'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1588.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1566.002'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'SUNBURST'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1566.001'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1105'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1204.001'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'WellMess'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T1068'},
#  {'name': 'APT28', 'type': 'uses', 'malware': 'Fysbis'},
#  {'name': 'APT32', 'type': 'uses', 'malware': 'Goopy'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1218.010'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1140'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1070.003'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1007'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1021.002'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'VaporRage'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1190'},
#  {'name': 'APT41', 'type': 'uses', 'malware': 'Derusbi'},
#  {'name': 'APT28', 'type': 'uses', 'malware': 'LoJax'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1110'},
#  {'name': 'APT1', 'type': 'uses', 'ttp': 'T1021.001'},
#  {'name': 'APT30', 'type': 'uses', 'malware': 'SPACESHIP'},
#  {'name': 'APT37', 'type': 'uses', 'ttp': 'T1561.002'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'DOGCALL'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1036.004'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1033'},
#  {'name': 'APT29', 'type': 'uses', 'malware': 'LiteDuke'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1059.005'},
#  {'name': 'APT19', 'type': 'uses', 'ttp': 'T1027.010'},
#  {'name': 'APT17', 'type': 'uses', 'ttp': 'T1585'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1548.002'},
#  {'name': 'APT37', 'type': 'uses', 'malware': 'WINERACK'},
#  {'name': 'APT32', 'type': 'uses', 'ttp': 'T1102'},
#  {'name': 'APT28', 'type': 'uses', 'ttp': 'T1021.002'},
#  {'name': 'APT39', 'type': 'uses', 'ttp': 'T1021.004'},
#  {'name': 'APT3', 'type': 'uses', 'ttp': 'T1027.005'},
#  {'name': 'APT29', 'type': 'uses', 'ttp': 'T1027.002'},
#  {'name': 'APT41', 'type': 'uses', 'ttp': 'T1574.001'},
#  {'name': 'APT28', 'type': 'uses', 'malware': 'X-Agent for Android'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T0852'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T0865'},
#  {'name': 'APT33', 'type': 'uses', 'ttp': 'T0853'},
#  {'name': 'APT38', 'type': 'uses', 'malware': 'KillDisk'}]

# %%
node_queries = []
relationship_queries = []
processed_names = set()
processed_ttps = set()
processed_malware = set()

for item in qu:
    if 'name' in item:
        name = item['name']
        if name not in processed_names:
            node_query = f"CREATE (:Threat_actor {{name: '{name}'}})"
            node_queries.append(node_query)
            processed_names.add(name)

    if 'ttp' in item:
        ttp = item['ttp']
        if ttp not in processed_ttps:
            node_query = f"CREATE (:TTP {{ttp: '{ttp}'}})"
            node_queries.append(node_query)
            processed_ttps.add(ttp)

        relationship_query = f"MATCH (n:Threat_actor {{name: '{item['name']}'}}), (t:TTP {{ttp: '{ttp}'}})\nCREATE (n)-[:USES]->(t);"
        relationship_queries.append(relationship_query)

    elif 'malware' in item:
        malware = item['malware']
        if malware not in processed_malware:
            node_query = f"CREATE (:Malware {{malware: '{malware}'}})"
            node_queries.append(node_query)
            processed_malware.add(malware)

        relationship_query = f"MATCH (n:Threat_actor {{name: '{item['name']}'}}), (m:Malware {{malware: '{malware}'}})\nCREATE (n)-[:USES]->(m);"
        relationship_queries.append(relationship_query)


for query in node_queries + relationship_queries:
    print(query)
# Out:
# CREATE (:Threat_actor {name: 'APT28'})
# CREATE (:TTP {ttp: 'T1003.003'})
# CREATE (:Threat_actor {name: 'APT29'})
# CREATE (:Malware {malware: 'PinchDuke'})
# CREATE (:Threat_actor {name: 'APT39'})
# CREATE (:TTP {ttp: 'T1046'})
# CREATE (:Threat_actor {name: 'APT38'})
# CREATE (:TTP {ttp: 'T1486'})
# CREATE (:Threat_actor {name: 'APT19'})
# CREATE (:TTP {ttp: 'T1547.001'})
# CREATE (:Malware {malware: 'WellMail'})
# CREATE (:Threat_actor {name: 'APT37'})
# CREATE (:Threat_actor {name: 'APT41'})
# CREATE (:TTP {ttp: 'T1078'})
# CREATE (:Malware {malware: 'CozyCar'})
# CREATE (:TTP {ttp: 'T1589.001'})
# CREATE (:TTP {ttp: 'T1033'})
# CREATE (:TTP {ttp: 'T1090.002'})
# CREATE (:Threat_actor {name: 'APT32'})
# CREATE (:TTP {ttp: 'T1550.002'})
# CREATE (:TTP {ttp: 'T1140'})
# CREATE (:Threat_actor {name: 'APT30'})
# CREATE (:Malware {malware: 'SHIPSHAPE'})
# CREATE (:TTP {ttp: 'T1564.001'})
# CREATE (:TTP {ttp: 'T1120'})
# CREATE (:Threat_actor {name: 'APT12'})
# CREATE (:TTP {ttp: 'T1204.002'})
# CREATE (:Threat_actor {name: 'APT3'})
# CREATE (:TTP {ttp: 'T1053.005'})
# CREATE (:TTP {ttp: 'T1621'})
# CREATE (:TTP {ttp: 'T1112'})
# CREATE (:TTP {ttp: 'T1583.001'})
# CREATE (:TTP {ttp: 'T1059.006'})
# CREATE (:TTP {ttp: 'T1036'})
# CREATE (:TTP {ttp: 'T1056.001'})
# CREATE (:TTP {ttp: 'T1005'})
# CREATE (:Threat_actor {name: 'APT1'})
# CREATE (:Malware {malware: 'Seasalt'})
# CREATE (:TTP {ttp: 'T1059.001'})
# CREATE (:TTP {ttp: 'T1115'})
# CREATE (:TTP {ttp: 'T1003'})
# CREATE (:TTP {ttp: 'T1070.006'})
# CREATE (:Malware {malware: 'ECCENTRICBANDWAGON'})
# CREATE (:TTP {ttp: 'T1195.002'})
# CREATE (:Malware {malware: 'TrailBlazer'})
# CREATE (:TTP {ttp: 'T1049'})
# CREATE (:TTP {ttp: 'T1104'})
# CREATE (:TTP {ttp: 'T1110.002'})
# CREATE (:Malware {malware: 'OnionDuke'})
# CREATE (:TTP {ttp: 'T1566.001'})
# CREATE (:Malware {malware: 'ASPXSpy'})
# CREATE (:TTP {ttp: 'T1070.004'})
# CREATE (:Threat_actor {name: 'APT33'})
# CREATE (:TTP {ttp: 'T1552.001'})
# CREATE (:TTP {ttp: 'T1048.002'})
# CREATE (:TTP {ttp: 'T1553.006'})
# CREATE (:Malware {malware: 'OSInfo'})
# CREATE (:TTP {ttp: 'T1003.005'})
# CREATE (:TTP {ttp: 'T1059.007'})
# CREATE (:Malware {malware: 'BLUELIGHT'})
# CREATE (:TTP {ttp: 'T1047'})
# CREATE (:TTP {ttp: 'T1546.010'})
# CREATE (:TTP {ttp: 'T1105'})
# CREATE (:Malware {malware: 'BISCUIT'})
# CREATE (:Threat_actor {name: 'APT18'})
# CREATE (:TTP {ttp: 'T1027'})
# CREATE (:TTP {ttp: 'T1203'})
# CREATE (:TTP {ttp: 'T1586.002'})
# CREATE (:TTP {ttp: 'T1114.002'})
# CREATE (:TTP {ttp: 'T1014'})
# CREATE (:TTP {ttp: 'T1564.003'})
# CREATE (:TTP {ttp: 'T1518.001'})
# CREATE (:TTP {ttp: 'T1072'})
# CREATE (:Malware {malware: 'CORALDECK'})
# CREATE (:TTP {ttp: 'T1071.001'})
# CREATE (:TTP {ttp: 'T1570'})
# CREATE (:TTP {ttp: 'T1564.004'})
# CREATE (:TTP {ttp: 'T1560.001'})
# CREATE (:TTP {ttp: 'T1505.003'})
# CREATE (:TTP {ttp: 'T1027.003'})
# CREATE (:TTP {ttp: 'T1543.003'})
# CREATE (:Threat_actor {name: 'APT-C-36'})
# CREATE (:Malware {malware: 'KARAE'})
# CREATE (:Malware {malware: 'MechaFlounder'})
# CREATE (:Malware {malware: 'PlugX'})
# CREATE (:TTP {ttp: 'T1588.002'})
# CREATE (:TTP {ttp: 'T1037.001'})
# CREATE (:Malware {malware: 'CHOPSTICK'})
# CREATE (:Malware {malware: 'AutoIt backdoor'})
# CREATE (:TTP {ttp: 'T1547.009'})
# CREATE (:Malware {malware: 'SLOWDRIFT'})
# CREATE (:Malware {malware: 'FatDuke'})
# CREATE (:TTP {ttp: 'T1090.004'})
# CREATE (:TTP {ttp: 'T1036.005'})
# CREATE (:TTP {ttp: 'T1003.001'})
# CREATE (:Malware {malware: 'Remexi'})
# CREATE (:TTP {ttp: 'T1090.003'})
# CREATE (:TTP {ttp: 'T1567'})
# CREATE (:TTP {ttp: 'T1071.002'})
# CREATE (:TTP {ttp: 'T1189'})
# CREATE (:TTP {ttp: 'T1068'})
# CREATE (:Malware {malware: 'POSHSPY'})
# CREATE (:TTP {ttp: 'T1083'})
# CREATE (:TTP {ttp: 'T1552.002'})
# CREATE (:TTP {ttp: 'T1135'})
# CREATE (:Malware {malware: 'EnvyScout'})
# CREATE (:TTP {ttp: 'T1553.002'})
# CREATE (:TTP {ttp: 'T1016'})
# CREATE (:Malware {malware: 'GLOOXMAIL'})
# CREATE (:TTP {ttp: 'T1190'})
# CREATE (:TTP {ttp: 'T1102.002'})
# CREATE (:TTP {ttp: 'T1546.003'})
# CREATE (:Malware {malware: 'Kerrdown'})
# CREATE (:TTP {ttp: 'T1569.002'})
# CREATE (:Malware {malware: 'SoreFang'})
# CREATE (:TTP {ttp: 'T1055'})
# CREATE (:TTP {ttp: 'T1216.001'})
# CREATE (:TTP {ttp: 'T1098'})
# CREATE (:Malware {malware: 'gh0st RAT'})
# CREATE (:TTP {ttp: 'T1057'})
# CREATE (:TTP {ttp: 'T1555.003'})
# CREATE (:TTP {ttp: 'T1136.003'})
# CREATE (:TTP {ttp: 'T1021.002'})
# CREATE (:TTP {ttp: 'T1059.003'})
# CREATE (:Malware {malware: 'GeminiDuke'})
# CREATE (:TTP {ttp: 'T1133'})
# CREATE (:TTP {ttp: 'T1218.011'})
# CREATE (:TTP {ttp: 'T1098.005'})
# CREATE (:TTP {ttp: 'T1587.003'})
# CREATE (:TTP {ttp: 'T1552.006'})
# CREATE (:TTP {ttp: 'T1651'})
# CREATE (:TTP {ttp: 'T1082'})
# CREATE (:TTP {ttp: 'T1571'})
# CREATE (:TTP {ttp: 'T1136.001'})
# CREATE (:Malware {malware: 'HOPLIGHT'})
# CREATE (:Threat_actor {name: 'APT17'})
# CREATE (:TTP {ttp: 'T1583.006'})
# CREATE (:TTP {ttp: 'T1039'})
# CREATE (:TTP {ttp: 'T1021.001'})
# CREATE (:TTP {ttp: 'T1078.004'})
# CREATE (:TTP {ttp: 'T1059.005'})
# CREATE (:TTP {ttp: 'T1012'})
# CREATE (:TTP {ttp: 'T1027.010'})
# CREATE (:TTP {ttp: 'T1048.003'})
# CREATE (:Malware {malware: 'PoisonIvy'})
# CREATE (:TTP {ttp: 'T1542.003'})
# CREATE (:Malware {malware: 'GoldMax'})
# CREATE (:TTP {ttp: 'T1113'})
# CREATE (:TTP {ttp: 'T1036.001'})
# CREATE (:Malware {malware: 'WEBC2'})
# CREATE (:TTP {ttp: 'T1548.002'})
# CREATE (:TTP {ttp: 'T1110.001'})
# CREATE (:TTP {ttp: 'T1070.001'})
# CREATE (:TTP {ttp: 'T1027.002'})
# CREATE (:TTP {ttp: 'T1119'})
# CREATE (:TTP {ttp: 'T1041'})
# CREATE (:Malware {malware: 'ZxShell'})
# CREATE (:TTP {ttp: 'T1587.001'})
# CREATE (:Malware {malware: 'Cobalt Strike'})
# CREATE (:TTP {ttp: 'T1574.002'})
# CREATE (:TTP {ttp: 'T1059'})
# CREATE (:Malware {malware: 'FoggyWeb'})
# CREATE (:TTP {ttp: 'T1480.001'})
# CREATE (:Malware {malware: 'DealersChoice'})
# CREATE (:TTP {ttp: 'T1529'})
# CREATE (:TTP {ttp: 'T1595.002'})
# CREATE (:TTP {ttp: 'T1546.015'})
# CREATE (:Malware {malware: 'KEYPLUG'})
# CREATE (:Malware {malware: 'SOUNDBITE'})
# CREATE (:TTP {ttp: 'T1199'})
# CREATE (:Malware {malware: 'OSX_OCEANLOTUS.D'})
# CREATE (:TTP {ttp: 'T1566.002'})
# CREATE (:Malware {malware: 'NanoCore'})
# CREATE (:TTP {ttp: 'T1598.003'})
# CREATE (:TTP {ttp: 'T1027.006'})
# CREATE (:TTP {ttp: 'T1562.003'})
# CREATE (:TTP {ttp: 'T1036.004'})
# CREATE (:Malware {malware: 'KOMPROGO'})
# CREATE (:TTP {ttp: 'T1087.001'})
# CREATE (:TTP {ttp: 'T1550.003'})
# CREATE (:Malware {malware: 'Cadelspy'})
# CREATE (:TTP {ttp: 'T1498'})
# CREATE (:Malware {malware: 'ADVSTORESHELL'})
# CREATE (:Malware {malware: 'Cannon'})
# CREATE (:TTP {ttp: 'T1204.001'})
# CREATE (:Malware {malware: 'Komplex'})
# CREATE (:TTP {ttp: 'T1560'})
# CREATE (:Malware {malware: 'StoneDrill'})
# CREATE (:TTP {ttp: 'T1217'})
# CREATE (:TTP {ttp: 'T1568.003'})
# CREATE (:TTP {ttp: 'T1598'})
# CREATE (:TTP {ttp: 'T1053.002'})
# CREATE (:TTP {ttp: 'T1559.002'})
# CREATE (:Malware {malware: 'PolyglotDuke'})
# CREATE (:TTP {ttp: 'T1608.004'})
# CREATE (:TTP {ttp: 'T1110.003'})
# CREATE (:Malware {malware: 'POWERTON'})
# CREATE (:TTP {ttp: 'T1078.003'})
# CREATE (:TTP {ttp: 'T1589'})
# CREATE (:Malware {malware: 'HIDEDRV'})
# CREATE (:Malware {malware: 'MiniDuke'})
# CREATE (:TTP {ttp: 'T1546.008'})
# CREATE (:TTP {ttp: 'T1221'})
# CREATE (:Malware {malware: 'China Chopper'})
# CREATE (:TTP {ttp: 'T1027.001'})
# CREATE (:TTP {ttp: 'T1213.002'})
# CREATE (:TTP {ttp: 'T1114.001'})
# CREATE (:Malware {malware: 'JHUHUGIT'})
# CREATE (:Malware {malware: 'Ixeshe'})
# CREATE (:TTP {ttp: 'T1071.003'})
# CREATE (:TTP {ttp: 'T1485'})
# CREATE (:TTP {ttp: 'T1025'})
# CREATE (:Malware {malware: 'CALENDAR'})
# CREATE (:Malware {malware: 'ShadowPad'})
# CREATE (:Malware {malware: 'TEARDROP'})
# CREATE (:TTP {ttp: 'T1556.007'})
# CREATE (:Malware {malware: 'ROKRAT'})
# CREATE (:TTP {ttp: 'T1588.001'})
# CREATE (:TTP {ttp: 'T1562.001'})
# CREATE (:Malware {malware: 'hcdLoader'})
# CREATE (:TTP {ttp: 'T1110'})
# CREATE (:TTP {ttp: 'T1574.006'})
# CREATE (:Threat_actor {name: 'APT16'})
# CREATE (:TTP {ttp: 'T1584.004'})
# CREATE (:TTP {ttp: 'T1106'})
# CREATE (:TTP {ttp: 'T1568.002'})
# CREATE (:Malware {malware: 'SHUTTERSPEED'})
# CREATE (:TTP {ttp: 'T1071.004'})
# CREATE (:TTP {ttp: 'T1074.001'})
# CREATE (:TTP {ttp: 'T1078.002'})
# CREATE (:TTP {ttp: 'T1555'})
# CREATE (:TTP {ttp: 'T1027.011'})
# CREATE (:TTP {ttp: 'T1213'})
# CREATE (:Malware {malware: 'SeaDuke'})
# CREATE (:TTP {ttp: 'T1565.002'})
# CREATE (:Malware {malware: 'XTunnel'})
# CREATE (:TTP {ttp: 'T1021.007'})
# CREATE (:Malware {malware: 'Drovorub'})
# CREATE (:Malware {malware: 'Pisloader'})
# CREATE (:Malware {malware: 'MESSAGETAP'})
# CREATE (:TTP {ttp: 'T1561.002'})
# CREATE (:TTP {ttp: 'T1018'})
# CREATE (:TTP {ttp: 'T1102.001'})
# CREATE (:TTP {ttp: 'T1008'})
# CREATE (:Malware {malware: 'BACKSPACE'})
# CREATE (:TTP {ttp: 'T1003.004'})
# CREATE (:TTP {ttp: 'T1036.003'})
# CREATE (:TTP {ttp: 'T1585.002'})
# CREATE (:TTP {ttp: 'T1496'})
# CREATE (:TTP {ttp: 'T1608.001'})
# CREATE (:Malware {malware: 'FLASHFLOOD'})
# CREATE (:Malware {malware: 'BLACKCOFFEE'})
# CREATE (:Malware {malware: 'Sibot'})
# CREATE (:TTP {ttp: 'T1210'})
# CREATE (:Malware {malware: 'TURNEDUP'})
# CREATE (:Malware {malware: 'POORAIM'})
# CREATE (:TTP {ttp: 'T1222.002'})
# CREATE (:Malware {malware: 'Raindrop'})
# CREATE (:TTP {ttp: 'T1586.003'})
# CREATE (:Malware {malware: 'RegDuke'})
# CREATE (:Malware {malware: 'NETEAGLE'})
# CREATE (:Malware {malware: 'CloudDuke'})
# CREATE (:TTP {ttp: 'T1218.005'})
# CREATE (:TTP {ttp: 'T1573'})
# CREATE (:TTP {ttp: 'T1059.004'})
# CREATE (:Malware {malware: 'njRAT'})
# CREATE (:TTP {ttp: 'T1550.001'})
# CREATE (:Malware {malware: 'GoldFinder'})
# CREATE (:TTP {ttp: 'T1566.003'})
# CREATE (:TTP {ttp: 'T1040'})
# CREATE (:TTP {ttp: 'T1030'})
# CREATE (:TTP {ttp: 'T1134.001'})
# CREATE (:Malware {malware: 'CORESHELL'})
# CREATE (:Malware {malware: 'HAPPYWORK'})
# CREATE (:Malware {malware: 'PHOREAL'})
# CREATE (:Malware {malware: 'ELMER'})
# CREATE (:Malware {malware: 'OLDBAIT'})
# CREATE (:Malware {malware: 'NativeZone'})
# CREATE (:TTP {ttp: 'T1074.002'})
# CREATE (:TTP {ttp: 'T1562.004'})
# CREATE (:TTP {ttp: 'T1584.001'})
# CREATE (:TTP {ttp: 'T1218.001'})
# CREATE (:TTP {ttp: 'T1565.003'})
# CREATE (:TTP {ttp: 'T1092'})
# CREATE (:TTP {ttp: 'T1197'})
# CREATE (:TTP {ttp: 'T1098.002'})
# CREATE (:TTP {ttp: 'T1553.005'})
# CREATE (:Malware {malware: 'NETWIRE'})
# CREATE (:Malware {malware: 'Downdelph'})
# CREATE (:TTP {ttp: 'T1649'})
# CREATE (:TTP {ttp: 'T1090'})
# CREATE (:Malware {malware: 'KillDisk'})
# CREATE (:TTP {ttp: 'T1087.004'})
# CREATE (:Malware {malware: 'SUNSPOT'})
# CREATE (:Malware {malware: 'XAgentOSX'})
# CREATE (:TTP {ttp: 'T1565.001'})
# CREATE (:TTP {ttp: 'T1137.002'})
# CREATE (:Malware {malware: 'ROCKBOOT'})
# CREATE (:TTP {ttp: 'T1132.001'})
# CREATE (:Malware {malware: 'RIPTIDE'})
# CREATE (:Malware {malware: 'USBStealer'})
# CREATE (:Malware {malware: 'Zebrocy'})
# CREATE (:TTP {ttp: 'T1528'})
# CREATE (:Malware {malware: 'SHOTPUT'})
# CREATE (:Malware {malware: 'WINDSHIELD'})
# CREATE (:Malware {malware: 'PowerDuke'})
# CREATE (:TTP {ttp: 'T1001.001'})
# CREATE (:TTP {ttp: 'T1589.002'})
# CREATE (:TTP {ttp: 'T1053.003'})
# CREATE (:TTP {ttp: 'T1095'})
# CREATE (:Malware {malware: 'HAMMERTOSS'})
# CREATE (:TTP {ttp: 'T1218.010'})
# CREATE (:TTP {ttp: 'T1573.001'})
# CREATE (:Malware {malware: 'BoomBox'})
# CREATE (:TTP {ttp: 'T1585.001'})
# CREATE (:Malware {malware: 'Final1stspy'})
# CREATE (:TTP {ttp: 'T1137'})
# CREATE (:Malware {malware: 'Denis'})
# CREATE (:TTP {ttp: 'T1090.001'})
# CREATE (:TTP {ttp: 'T1211'})
# CREATE (:TTP {ttp: 'T1069'})
# CREATE (:TTP {ttp: 'T1123'})
# CREATE (:TTP {ttp: 'T1059.009'})
# CREATE (:Malware {malware: 'NavRAT'})
# CREATE (:Malware {malware: 'HTTPBrowser'})
# CREATE (:Malware {malware: 'DarkComet'})
# CREATE (:TTP {ttp: 'T1091'})
# CREATE (:Malware {malware: 'CosmicDuke'})
# CREATE (:TTP {ttp: 'T1056'})
# CREATE (:Malware {malware: 'RemoteCMD'})
# CREATE (:Malware {malware: 'Winnti for Linux'})
# CREATE (:Malware {malware: 'SUNBURST'})
# CREATE (:Malware {malware: 'WellMess'})
# CREATE (:Malware {malware: 'Fysbis'})
# CREATE (:Malware {malware: 'Goopy'})
# CREATE (:TTP {ttp: 'T1070.003'})
# CREATE (:TTP {ttp: 'T1007'})
# CREATE (:Malware {malware: 'VaporRage'})
# CREATE (:Malware {malware: 'Derusbi'})
# CREATE (:Malware {malware: 'LoJax'})
# CREATE (:Malware {malware: 'SPACESHIP'})
# CREATE (:Malware {malware: 'DOGCALL'})
# CREATE (:Malware {malware: 'LiteDuke'})
# CREATE (:TTP {ttp: 'T1585'})
# CREATE (:Malware {malware: 'WINERACK'})
# CREATE (:TTP {ttp: 'T1102'})
# CREATE (:TTP {ttp: 'T1021.004'})
# CREATE (:TTP {ttp: 'T1027.005'})
# CREATE (:TTP {ttp: 'T1574.001'})
# CREATE (:Malware {malware: 'X-Agent for Android'})
# CREATE (:TTP {ttp: 'T0852'})
# CREATE (:TTP {ttp: 'T0865'})
# CREATE (:TTP {ttp: 'T0853'})
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1003.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'PinchDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1046'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1486'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'WellMail'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1078'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'CozyCar'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1589.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1033'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1090.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1550.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1140'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT30'}), (m:Malware {malware: 'SHIPSHAPE'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1564.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1120'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT12'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1053.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1621'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1112'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1583.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1059.006'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1036'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1056.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (m:Malware {malware: 'Seasalt'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1115'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1070.006'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (m:Malware {malware: 'ECCENTRICBANDWAGON'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1090.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1195.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'TrailBlazer'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1049'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1104'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1110.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'OnionDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'ASPXSpy'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1070.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1552.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1048.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1553.006'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (m:Malware {malware: 'OSInfo'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1003.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1059.007'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'BLUELIGHT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1047'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1546.010'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1105'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (m:Malware {malware: 'BISCUIT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1056.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1078'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1027'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1203'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1586.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1114.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1014'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1564.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1518.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1072'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'CORALDECK'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1071.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1570'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1564.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1560.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1505.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1027.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1543.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT-C-36'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'KARAE'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (m:Malware {malware: 'MechaFlounder'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'PlugX'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1550.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1588.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1037.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1027'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'CHOPSTICK'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1588.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (m:Malware {malware: 'AutoIt backdoor'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1547.009'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'SLOWDRIFT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 
003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1133'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1027.011'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1213'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'SeaDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1565.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1218.011'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1560.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1140'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1203'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'XTunnel'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1113'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1021.007'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1105'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1003.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'Drovorub'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT18'}), (m:Malware {malware: 'Pisloader'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'MESSAGETAP'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1561.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1018'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1102.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1021.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1008'})
# CREATE (n)-[:USES]->(t);
# ...
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1553.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (m:Malware {malware: 'NETWIRE'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1036.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1564.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1112'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'Downdelph'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1059.006'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1003.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1649'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1106'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1059.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1090'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (m:Malware {malware: 'KillDisk'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1040'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1003.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1016'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1218.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1068'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1087.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'SUNSPOT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'XAgentOSX'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1087.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1565.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1137.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'ROCKBOOT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1132.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT12'}), (m:Malware {malware: 'RIPTIDE'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'USBStealer'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1021.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'Zebrocy'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1197'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1528'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1078'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT-C-36'}), (t:TTP {ttp: 'T1059.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1027.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1110.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1036.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1204.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1071.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1133'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (m:Malware {malware: 'SHOTPUT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1083'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'Cobalt Strike'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT32'}), (m:Malware {malware: 'WINDSHIELD'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1059.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1071.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1098.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'PowerDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1102.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1057'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT-C-36'}), (t:TTP {ttp: 'T1571'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1049'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1564.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1027'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1001.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1056.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1589.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1053.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1095'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'HAMMERTOSS'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1218.010'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1068'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1573.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1135'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1055'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'BoomBox'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1059.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1585.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1132.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'Final1stspy'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1137'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1203'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (m:Malware {malware: 'Denis'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1090.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1083'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1059.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1211'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1069'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'Cobalt Strike'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1546.008'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1123'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1588.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1571'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1059.009'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'NavRAT'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1003.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1018'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1586.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1021.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1059.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1190'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1078.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1203'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT18'}), (m:Malware {malware: 'HTTPBrowser'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT38'}), (m:Malware {malware: 'DarkComet'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1078'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1573.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1059.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1074.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1056.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1091'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT-C-36'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'CosmicDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1027.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1569.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1136.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1056'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1027'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1104'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (m:Malware {malware: 'RemoteCMD'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1574.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1047'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1204.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'Winnti for Linux'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1056.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1547.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (t:TTP {ttp: 'T1057'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1053.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1588.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1566.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'SUNBURST'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1566.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1105'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1204.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'WellMess'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T1068'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'Fysbis'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT32'}), (m:Malware {malware: 'Goopy'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1218.010'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1140'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1070.003'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1007'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1021.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'VaporRage'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1190'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (m:Malware {malware: 'Derusbi'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'LoJax'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1110'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT1'}), (t:TTP {ttp: 'T1021.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT30'}), (m:Malware {malware: 'SPACESHIP'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT37'}), (t:TTP {ttp: 'T1561.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'DOGCALL'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1036.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1033'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (m:Malware {malware: 'LiteDuke'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1059.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT19'}), (t:TTP {ttp: 'T1027.010'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT17'}), (t:TTP {ttp: 'T1585'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1548.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT37'}), (m:Malware {malware: 'WINERACK'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT32'}), (t:TTP {ttp: 'T1102'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (t:TTP {ttp: 'T1021.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT39'}), (t:TTP {ttp: 'T1021.004'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT3'}), (t:TTP {ttp: 'T1027.005'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT29'}), (t:TTP {ttp: 'T1027.002'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT41'}), (t:TTP {ttp: 'T1574.001'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT28'}), (m:Malware {malware: 'X-Agent for Android'})
# CREATE (n)-[:USES]->(m);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T0852'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T0865'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT33'}), (t:TTP {ttp: 'T0853'})
# CREATE (n)-[:USES]->(t);
# MATCH (n:Threat_actor {name: 'APT38'}), (m:Malware {malware: 'KillDisk'})
# CREATE (n)-[:USES]->(m);
